# %% [markdown]
# # Graphs
#
# Hello and welcome. In this first Notebook I'll go over the graph structures used: graph1-graph4:
#
# - graph1: **Identity**
# - graph2: **Geographical Contiguity**
# - graph3: **Random** with `k = 3`
# - graph4: **Random** with `k = 4`
#
# While it's the same arguments used for each graph type over different scenarios, the final graphs look different depending on the scenario.

# %%
import logging
logging.basicConfig(level=logging.ERROR, format="%(asctime)s %(name)s %(levelname)s %(message)s")

# %% [markdown]
# ## Construction

# %%
from src.graphconstruction import GraphManager

# %%
# Init the graph-managers
gm_de_nuts3 = GraphManager('germany','nuts3')
gm_de_nuts2 = GraphManager('germany','nuts2')
gm_de_nuts1 = GraphManager('germany','nuts1')
gm_hu_nuts3 = GraphManager('hungary','nuts3')

# %%
# Graphs:

args1 = {
    'graph_name'            : 'graph1',
    'graph_type'            : 'identity',
    'normalization_method'  : 'none'
    }

args2 = {
    'graph_name'            : 'graph2',
    'graph_type'            : 'geographical_contiguity',
    'normalization_method'  : 'none'
    }

args3 = {
    'graph_name'            : 'graph3',
    'graph_type'            : 'random',
    'normalization_method'  : 'none',
    'seed'                  : 42,
    'k'                     : 3
    }

args4 = {
    'graph_name'            : 'graph4',
    'graph_type'            : 'random',
    'normalization_method'  : 'none',
    'seed'                  : 109548,
    'k'                     : 4
    }

args5 = {
    'graph_name'            : 'graph5',
    'graph_type'            : 'random',
    'normalization_method'  : 'none',
    'seed'                  : 123,
    'k'                     : 5
    }

args6 = {
    'graph_name'            : 'graph6',
    'graph_type'            : 'random',
    'normalization_method'  : 'none',
    'seed'                  : 456,
    'k'                     : 6
    }

# %%
gm_de_nuts3.construct_graph(**args1)    # type: ignore
gm_de_nuts3.construct_graph(**args2)    # type: ignore
gm_de_nuts3.construct_graph(**args3)    # type: ignore
gm_de_nuts3.construct_graph(**args4)    # type: ignore
gm_de_nuts3.construct_graph(**args5)    # type: ignore
gm_de_nuts3.construct_graph(**args6)    # type: ignore

# %%
gm_de_nuts2.construct_graph(**args1)    # type: ignore
gm_de_nuts2.construct_graph(**args2)    # type: ignore
gm_de_nuts2.construct_graph(**args3)    # type: ignore
gm_de_nuts2.construct_graph(**args4)    # type: ignore
gm_de_nuts2.construct_graph(**args5)    # type: ignore
gm_de_nuts2.construct_graph(**args6)    # type: ignore

# %%
gm_de_nuts1.construct_graph(**args1)    # type: ignore
gm_de_nuts1.construct_graph(**args2)    # type: ignore
gm_de_nuts1.construct_graph(**args3)    # type: ignore
gm_de_nuts1.construct_graph(**args4)    # type: ignore
gm_de_nuts1.construct_graph(**args5)    # type: ignore
gm_de_nuts1.construct_graph(**args6)    # type: ignore

# %%
gm_hu_nuts3.construct_graph(**args1)    # type: ignore
gm_hu_nuts3.construct_graph(**args2)    # type: ignore
gm_hu_nuts3.construct_graph(**args3)    # type: ignore
gm_hu_nuts3.construct_graph(**args4)    # type: ignore
gm_hu_nuts3.construct_graph(**args5)    # type: ignore
gm_hu_nuts3.construct_graph(**args6)    # type: ignore

# %% [markdown]
# ## Preview

# %%
gm_hu_nuts3.preview('graph1','network','global','map',None,'in')
gm_hu_nuts3.preview('graph2','network','global','map',None,'in')
gm_hu_nuts3.preview('graph3','network','global','map',None,'in')
gm_hu_nuts3.preview('graph4','network','global','map',None,'in')
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <Axes: title={'center': 'Network - global - IN'}>)

# %%
# Init the graph-managers
gm_de_nuts3.graph_registry.save_all_entries(True)
gm_de_nuts2.graph_registry.save_all_entries(True)
gm_de_nuts1.graph_registry.save_all_entries(True)
gm_hu_nuts3.graph_registry.save_all_entries(True)
