# %%
from src.utils import get_data_env
from src.models import GATv2Model, NodeRFModel
from src.dataloading import DeepDataLoader, ShallowDataLoader

disease_name    = 'influenza'
nuts_level      = 'nuts3'
min_date        ='2006-05-15'
max_date        = '2020-06-01'
split_trainval  = '2018-06-01'
split_valtest   = '2019-06-01'
split_berlin    = False


horizon_size    = 4
horizon_leadtime= 1
sequence_length = 1
lags            = 4

graphtype       = 'boolean_neighbors_self'
modelname       = 'boolean neighbors - spatial gcn'

# training hparams
n_epochs        = 150
lr              = 0.0001
min_delta       = 0
loss            = 'asymmetric_mse'

global_hparams = {
    "lr"                : lr,
    "n_epochs"          : n_epochs,
    "scheduler"         : 'plateau',
    "scheduler_kwargs"  :   {'mode': 'min', 'factor': 0.8, 'patience': 5},
    'min_delta'         : min_delta,
    'loss'              : loss,
    'patience'          : 20,
    }


logged_zscore = DeepDataLoader(disease_name, get_data_env(), nuts_level=nuts_level, min_date=min_date,max_date=max_date, include_population=False, horizon_size = horizon_size, horizon_leadtime = horizon_leadtime, sequence_length=sequence_length, split_berlin=split_berlin)
logged_zscore.add_time_features()
logged_zscore.log_transform_target()
logged_zscore.set_splits(split_trainval, split_valtest)
logged_zscore.normalize()
logged_zscore.add_lagged_features(lags = lags)
logged_zscore.finalize()

dl1 = logged_zscore.copy().retrieve_graph('boolean_neighbors_self').construct_dataloaders()

ml1      = GATv2Model(dl1, name = 'boolean neighbors graph')
ml1.set_model_hparams()
ml1.set_global_hparams(**global_hparams)
ml1.train(verbose = 2, dataloader_snapshot=False, show_loss= True)
ml1.forecast('test')
ml1.show_forecasts('test', [26,391, 69], show_all_horizons=True)

dl2 = logged_zscore.copy().retrieve_graph('gravity4').construct_dataloaders()

ml2      = GATv2Model(dl2, name = 'gravity model 4 graph')
ml2.set_model_hparams()
ml2.set_global_hparams(**global_hparams)
ml2.train(verbose = 2, dataloader_snapshot=False, show_loss= True)
ml2.forecast('test')
ml2.show_forecasts('test', [26,391, 69], show_all_horizons=True)

dl3 = logged_zscore.copy().retrieve_graph('commuter1').construct_dataloaders()

ml3      = GATv2Model(dl3, name = 'commuter 1 graph')
ml3.set_model_hparams()
ml3.set_global_hparams(**global_hparams)
ml3.train(verbose = 2, dataloader_snapshot=False, show_loss= True)
ml3.forecast('test')
ml3.show_forecasts('test', [26,391, 69], show_all_horizons=True)

epidata_loader_basis = ShallowDataLoader(disease_name, get_data_env(), nuts_level=nuts_level, min_date=min_date,max_date=max_date, include_population=False, horizon_size = horizon_size, horizon_leadtime = horizon_leadtime, sequence_length=sequence_length, split_berlin=split_berlin)
epidata_loader_basis.add_time_features()
epidata_loader_basis.log_transform_target()
epidata_loader_basis.set_splits(split_trainval, split_valtest)
epidata_loader_basis.normalize()
epidata_loader_basis.add_lagged_features(lags = lags)
epidata_loader_basis.finalize()

epidata_loader_basis.construct_dataloaders()

rfmodel = NodeRFModel(epidata_loader_basis, name = 'node RF')
rfmodel.set_global_hparams()
rfmodel.set_model_hparams()
rfmodel.train()
rfmodel.forecast('test')
rfmodel.show_forecasts('test',0, show_all_horizons=True)
# Out:
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-10 (+5 weeks)
# berlin districts removed
#
# ========================================
# ==  Training boolean neighbors graph  ==
# ========================================
# Epoch 1 train loss: 1.1275, val loss: 1.2506 ✓ (new best)
# Epoch 2 train loss: 0.9865, val loss: 1.1230 ✓ (new best)
# Epoch 3 train loss: 0.9246, val loss: 1.0476 ✓ (new best)
# Epoch 4 train loss: 0.8625, val loss: 1.0106 ✓ (new best)
# Epoch 5 train loss: 0.8259, val loss: 0.9873 ✓ (new best)
# Epoch 6 train loss: 0.7999, val loss: 0.9282 ✓ (new best)
# Epoch 7 train loss: 0.7727, val loss: 0.9163 ✓ (new best)
# Epoch 8 train loss: 0.7619, val loss: 0.8739 ✓ (new best)
# Epoch 9 train loss: 0.7397, val loss: 0.8462 ✓ (new best)
# Epoch 10 train loss: 0.7271, val loss: 0.8284 ✓ (new best)
# Epoch 11 train loss: 0.7212, val loss: 0.8364 (patience: 1/20)
# Epoch 12 train loss: 0.7138, val loss: 0.8088 ✓ (new best)
# Epoch 13 train loss: 0.7069, val loss: 0.8050 ✓ (new best)
# Epoch 14 train loss: 0.6965, val loss: 0.8047 ✓ (new best)
# Epoch 15 train loss: 0.6924, val loss: 0.7975 ✓ (new best)
# Epoch 16 train loss: 0.6841, val loss: 0.7897 ✓ (new best)
# Epoch 17 train loss: 0.6794, val loss: 0.7840 ✓ (new best)
# Epoch 18 train loss: 0.6758, val loss: 0.7964 (patience: 1/20)
# Epoch 19 train loss: 0.6708, val loss: 0.7821 ✓ (new best)
# Epoch 20 train loss: 0.6624, val loss: 0.8010 (patience: 1/20)
# Epoch 21 train loss: 0.6653, val loss: 0.8026 (patience: 2/20)
# Epoch 22 train loss: 0.6594, val loss: 0.7689 ✓ (new best)
# Epoch 23 train loss: 0.6551, val loss: 0.7833 (patience: 1/20)
# Epoch 24 train loss: 0.6520, val loss: 0.7810 (patience: 2/20)
# Epoch 25 train loss: 0.6453, val loss: 0.7948 (patience: 3/20)
# Epoch 26 train loss: 0.6493, val loss: 0.7925 (patience: 4/20)
# Epoch 27 train loss: 0.6397, val loss: 0.7809 (patience: 5/20)
# Epoch 28 train loss: 0.6400, val loss: 0.7978 (patience: 6/20)
# lr has been updated from 0.00010 to 0.00008
# Epoch 29 train loss: 0.6292, val loss: 0.7192 ✓ (new best)
# Epoch 30 train loss: 0.6205, val loss: 0.7130 ✓ (new best)
# Epoch 31 train loss: 0.6176, val loss: 0.7178 (patience: 1/20)
# Epoch 32 train loss: 0.6173, val loss: 0.7221 (patience: 2/20)
# Epoch 33 train loss: 0.6143, val loss: 0.7114 ✓ (new best)
# Epoch 34 train loss: 0.6104, val loss: 0.7059 ✓ (new best)
# Epoch 35 train loss: 0.6101, val loss: 0.7250 (patience: 1/20)
# Epoch 36 train loss: 0.6028, val loss: 0.7148 (patience: 2/20)
# Epoch 37 train loss: 0.6064, val loss: 0.7227 (patience: 3/20)
# Epoch 38 train loss: 0.6027, val loss: 0.7054 ✓ (new best)
# Epoch 39 train loss: 0.6024, val loss: 0.7231 (patience: 1/20)
# Epoch 40 train loss: 0.6001, val loss: 0.7117 (patience: 2/20)
# Epoch 41 train loss: 0.6025, val loss: 0.7047 ✓ (new best)
# Epoch 42 train loss: 0.5960, val loss: 0.7186 (patience: 1/20)
# Epoch 43 train loss: 0.5968, val loss: 0.6935 ✓ (new best)
# Epoch 44 train loss: 0.5914, val loss: 0.6869 ✓ (new best)
# Epoch 45 train loss: 0.5896, val loss: 0.6979 (patience: 1/20)
# Epoch 46 train loss: 0.5900, val loss: 0.6861 ✓ (new best)
# Epoch 47 train loss: 0.5910, val loss: 0.6927 (patience: 1/20)
# Epoch 48 train loss: 0.5871, val loss: 0.6807 ✓ (new best)
# Epoch 49 train loss: 0.5864, val loss: 0.6883 (patience: 1/20)
# Epoch 50 train loss: 0.5827, val loss: 0.6647 ✓ (new best)
# Epoch 51 train loss: 0.5792, val loss: 0.6796 (patience: 1/20)
# Epoch 52 train loss: 0.5832, val loss: 0.6796 (patience: 2/20)
# Epoch 53 train loss: 0.5773, val loss: 0.6625 ✓ (new best)
# Epoch 54 train loss: 0.5841, val loss: 0.6883 (patience: 1/20)
# Epoch 55 train loss: 0.5785, val loss: 0.6626 (patience: 2/20)
# Epoch 56 train loss: 0.5779, val loss: 0.6664 (patience: 3/20)
# Epoch 57 train loss: 0.5765, val loss: 0.6626 (patience: 4/20)
# Epoch 58 train loss: 0.5766, val loss: 0.6649 (patience: 5/20)
# Epoch 59 train loss: 0.5741, val loss: 0.6655 (patience: 6/20)
# lr has been updated from 0.00008 to 0.00006
# Epoch 60 train loss: 0.5673, val loss: 0.6242 ✓ (new best)
# Epoch 61 train loss: 0.5630, val loss: 0.6365 (patience: 1/20)
# Epoch 62 train loss: 0.5609, val loss: 0.6271 (patience: 2/20)
# Epoch 63 train loss: 0.5618, val loss: 0.6240 ✓ (new best)
# Epoch 64 train loss: 0.5607, val loss: 0.6313 (patience: 1/20)
# Epoch 65 train loss: 0.5588, val loss: 0.6371 (patience: 2/20)
# Epoch 66 train loss: 0.5595, val loss: 0.6257 (patience: 3/20)
# Epoch 67 train loss: 0.5543, val loss: 0.6258 (patience: 4/20)
# Epoch 68 train loss: 0.5570, val loss: 0.6257 (patience: 5/20)
# Epoch 69 train loss: 0.5568, val loss: 0.6367 (patience: 6/20)
# lr has been updated from 0.00006 to 0.00005
# Epoch 70 train loss: 0.5465, val loss: 0.6161 ✓ (new best)
# Epoch 71 train loss: 0.5471, val loss: 0.6138 ✓ (new best)
# Epoch 72 train loss: 0.5448, val loss: 0.6175 (patience: 1/20)
# Epoch 73 train loss: 0.5487, val loss: 0.6170 (patience: 2/20)
# Epoch 74 train loss: 0.5445, val loss: 0.6111 ✓ (new best)
# Epoch 75 train loss: 0.5424, val loss: 0.6195 (patience: 1/20)
# Epoch 76 train loss: 0.5466, val loss: 0.6138 (patience: 2/20)
# Epoch 77 train loss: 0.5442, val loss: 0.6164 (patience: 3/20)
# Epoch 78 train loss: 0.5402, val loss: 0.6189 (patience: 4/20)
# Epoch 79 train loss: 0.5403, val loss: 0.6155 (patience: 5/20)
# Epoch 80 train loss: 0.5394, val loss: 0.6139 (patience: 6/20)
# lr has been updated from 0.00005 to 0.00004
# Epoch 81 train loss: 0.5333, val loss: 0.6096 ✓ (new best)
# Epoch 82 train loss: 0.5330, val loss: 0.6105 (patience: 1/20)
# Epoch 83 train loss: 0.5336, val loss: 0.6102 (patience: 2/20)
# Epoch 84 train loss: 0.5337, val loss: 0.6085 ✓ (new best)
# Epoch 85 train loss: 0.5321, val loss: 0.6110 (patience: 1/20)
# Epoch 86 train loss: 0.5293, val loss: 0.6096 (patience: 2/20)
# Epoch 87 train loss: 0.5302, val loss: 0.6082 ✓ (new best)
# Epoch 88 train loss: 0.5309, val loss: 0.6091 (patience: 1/20)
# Epoch 89 train loss: 0.5319, val loss: 0.6078 ✓ (new best)
# Epoch 90 train loss: 0.5260, val loss: 0.6082 (patience: 1/20)
# Epoch 91 train loss: 0.5282, val loss: 0.6119 (patience: 2/20)
# Epoch 92 train loss: 0.5250, val loss: 0.6065 ✓ (new best)
# Epoch 93 train loss: 0.5232, val loss: 0.6086 (patience: 1/20)
# Epoch 94 train loss: 0.5286, val loss: 0.6115 (patience: 2/20)
# Epoch 95 train loss: 0.5240, val loss: 0.6113 (patience: 3/20)
# Epoch 96 train loss: 0.5262, val loss: 0.6094 (patience: 4/20)
# Epoch 97 train loss: 0.5269, val loss: 0.6093 (patience: 5/20)
# Epoch 98 train loss: 0.5238, val loss: 0.6107 (patience: 6/20)
# lr has been updated from 0.00004 to 0.00003
# Epoch 99 train loss: 0.5155, val loss: 0.6088 (patience: 7/20)
# Epoch 100 train loss: 0.5176, val loss: 0.6092 (patience: 8/20)
# Epoch 101 train loss: 0.5228, val loss: 0.6087 (patience: 9/20)
# Epoch 102 train loss: 0.5186, val loss: 0.6100 (patience: 10/20)
# Epoch 103 train loss: 0.5149, val loss: 0.6100 (patience: 11/20)
# Epoch 104 train loss: 0.5210, val loss: 0.6088 (patience: 12/20)
# lr has been updated from 0.00003 to 0.00003
# Epoch 105 train loss: 0.5181, val loss: 0.6144 (patience: 13/20)
# Epoch 106 train loss: 0.5119, val loss: 0.6119 (patience: 14/20)
# Epoch 107 train loss: 0.5138, val loss: 0.6122 (patience: 15/20)
# Epoch 108 train loss: 0.5152, val loss: 0.6108 (patience: 16/20)
# Epoch 109 train loss: 0.5105, val loss: 0.6105 (patience: 17/20)
# Epoch 110 train loss: 0.5112, val loss: 0.6113 (patience: 18/20)
# lr has been updated from 0.00003 to 0.00002
# Epoch 111 train loss: 0.5110, val loss: 0.6135 (patience: 19/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.6065
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████| 47/47 [00:00<00:00, 554.18it/s]
# Test loss: 0.9797
# ========================================
# ==   Training gravity model 4 graph   ==
# ========================================
# Epoch 1 train loss: 1.0776, val loss: 1.2065 ✓ (new best)
# Epoch 2 train loss: 0.9519, val loss: 1.3071 (patience: 1/20)
# Epoch 3 train loss: 0.9007, val loss: 1.1348 ✓ (new best)
# Epoch 4 train loss: 0.8513, val loss: 1.0958 ✓ (new best)
# Epoch 5 train loss: 0.8298, val loss: 1.0517 ✓ (new best)
# Epoch 6 train loss: 0.8107, val loss: 1.0015 ✓ (new best)
# Epoch 7 train loss: 0.7893, val loss: 0.9597 ✓ (new best)
# Epoch 8 train loss: 0.7721, val loss: 0.9246 ✓ (new best)
# Epoch 9 train loss: 0.7505, val loss: 0.9071 ✓ (new best)
# Epoch 10 train loss: 0.7408, val loss: 0.9078 (patience: 1/20)
# Epoch 11 train loss: 0.7314, val loss: 0.8940 ✓ (new best)
# Epoch 12 train loss: 0.7254, val loss: 0.8627 ✓ (new best)
# Epoch 13 train loss: 0.7099, val loss: 0.8765 (patience: 1/20)
# Epoch 14 train loss: 0.7109, val loss: 0.8564 ✓ (new best)
# Epoch 15 train loss: 0.7035, val loss: 0.8312 ✓ (new best)
# Epoch 16 train loss: 0.6890, val loss: 0.8162 ✓ (new best)
# Epoch 17 train loss: 0.6865, val loss: 0.8322 (patience: 1/20)
# Epoch 18 train loss: 0.6796, val loss: 0.7972 ✓ (new best)
# Epoch 19 train loss: 0.6707, val loss: 0.8149 (patience: 1/20)
# Epoch 20 train loss: 0.6672, val loss: 0.8067 (patience: 2/20)
# Epoch 21 train loss: 0.6605, val loss: 0.8385 (patience: 3/20)
# Epoch 22 train loss: 0.6554, val loss: 0.7873 ✓ (new best)
# Epoch 23 train loss: 0.6490, val loss: 0.7899 (patience: 1/20)
# Epoch 24 train loss: 0.6479, val loss: 0.8330 (patience: 2/20)
# Epoch 25 train loss: 0.6420, val loss: 0.7789 ✓ (new best)
# Epoch 26 train loss: 0.6359, val loss: 0.7985 (patience: 1/20)
# Epoch 27 train loss: 0.6364, val loss: 0.7877 (patience: 2/20)
# Epoch 28 train loss: 0.6303, val loss: 0.7888 (patience: 3/20)
# Epoch 29 train loss: 0.6257, val loss: 0.7906 (patience: 4/20)
# Epoch 30 train loss: 0.6269, val loss: 0.8014 (patience: 5/20)
# Epoch 31 train loss: 0.6204, val loss: 0.7662 ✓ (new best)
# Epoch 32 train loss: 0.6172, val loss: 0.8195 (patience: 1/20)
# Epoch 33 train loss: 0.6135, val loss: 0.8075 (patience: 2/20)
# Epoch 34 train loss: 0.6103, val loss: 0.7710 (patience: 3/20)
# Epoch 35 train loss: 0.6040, val loss: 0.7991 (patience: 4/20)
# Epoch 36 train loss: 0.6013, val loss: 0.8130 (patience: 5/20)
# Epoch 37 train loss: 0.6018, val loss: 0.7818 (patience: 6/20)
# lr has been updated from 0.00010 to 0.00008
# Epoch 38 train loss: 0.5881, val loss: 0.7175 ✓ (new best)
# Epoch 39 train loss: 0.5773, val loss: 0.7298 (patience: 1/20)
# Epoch 40 train loss: 0.5790, val loss: 0.7190 (patience: 2/20)
# Epoch 41 train loss: 0.5835, val loss: 0.7257 (patience: 3/20)
# Epoch 42 train loss: 0.5739, val loss: 0.6935 ✓ (new best)
# Epoch 43 train loss: 0.5720, val loss: 0.7260 (patience: 1/20)
# Epoch 44 train loss: 0.5699, val loss: 0.7237 (patience: 2/20)
# Epoch 45 train loss: 0.5670, val loss: 0.6876 ✓ (new best)
# Epoch 46 train loss: 0.5660, val loss: 0.7287 (patience: 1/20)
# Epoch 47 train loss: 0.5663, val loss: 0.6929 (patience: 2/20)
# Epoch 48 train loss: 0.5659, val loss: 0.7110 (patience: 3/20)
# Epoch 49 train loss: 0.5604, val loss: 0.6911 (patience: 4/20)
# Epoch 50 train loss: 0.5601, val loss: 0.7149 (patience: 5/20)
# Epoch 51 train loss: 0.5620, val loss: 0.6832 ✓ (new best)
# Epoch 52 train loss: 0.5553, val loss: 0.6869 (patience: 1/20)
# Epoch 53 train loss: 0.5579, val loss: 0.6843 (patience: 2/20)
# Epoch 54 train loss: 0.5540, val loss: 0.6896 (patience: 3/20)
# Epoch 55 train loss: 0.5543, val loss: 0.6823 ✓ (new best)
# Epoch 56 train loss: 0.5558, val loss: 0.6794 ✓ (new best)
# Epoch 57 train loss: 0.5516, val loss: 0.6564 ✓ (new best)
# Epoch 58 train loss: 0.5667, val loss: 0.6841 (patience: 1/20)
# Epoch 59 train loss: 0.5538, val loss: 0.6469 ✓ (new best)
# Epoch 60 train loss: 0.5561, val loss: 0.6841 (patience: 1/20)
# Epoch 61 train loss: 0.5501, val loss: 0.6750 (patience: 2/20)
# Epoch 62 train loss: 0.5507, val loss: 0.6662 (patience: 3/20)
# Epoch 63 train loss: 0.5441, val loss: 0.6712 (patience: 4/20)
# Epoch 64 train loss: 0.5513, val loss: 0.6592 (patience: 5/20)
# Epoch 65 train loss: 0.5446, val loss: 0.6729 (patience: 6/20)
# lr has been updated from 0.00008 to 0.00006
# Epoch 66 train loss: 0.5416, val loss: 0.6173 ✓ (new best)
# Epoch 67 train loss: 0.5301, val loss: 0.6290 (patience: 1/20)
# Epoch 68 train loss: 0.5321, val loss: 0.6331 (patience: 2/20)
# Epoch 69 train loss: 0.5290, val loss: 0.6328 (patience: 3/20)
# Epoch 70 train loss: 0.5288, val loss: 0.6243 (patience: 4/20)
# Epoch 71 train loss: 0.5278, val loss: 0.6204 (patience: 5/20)
# Epoch 72 train loss: 0.5252, val loss: 0.6324 (patience: 6/20)
# lr has been updated from 0.00006 to 0.00005
# Epoch 73 train loss: 0.5208, val loss: 0.6030 ✓ (new best)
# Epoch 74 train loss: 0.5187, val loss: 0.6044 (patience: 1/20)
# Epoch 75 train loss: 0.5186, val loss: 0.6067 (patience: 2/20)
# Epoch 76 train loss: 0.5173, val loss: 0.6074 (patience: 3/20)
# Epoch 77 train loss: 0.5174, val loss: 0.6083 (patience: 4/20)
# Epoch 78 train loss: 0.5135, val loss: 0.6035 (patience: 5/20)
# Epoch 79 train loss: 0.5139, val loss: 0.6009 ✓ (new best)
# Epoch 80 train loss: 0.5219, val loss: 0.6108 (patience: 1/20)
# Epoch 81 train loss: 0.5172, val loss: 0.6005 ✓ (new best)
# Epoch 82 train loss: 0.5158, val loss: 0.6019 (patience: 1/20)
# Epoch 83 train loss: 0.5127, val loss: 0.6121 (patience: 2/20)
# Epoch 84 train loss: 0.5173, val loss: 0.5978 ✓ (new best)
# Epoch 85 train loss: 0.5115, val loss: 0.6035 (patience: 1/20)
# Epoch 86 train loss: 0.5144, val loss: 0.5972 ✓ (new best)
# Epoch 87 train loss: 0.5108, val loss: 0.5987 (patience: 1/20)
# Epoch 88 train loss: 0.5103, val loss: 0.6016 (patience: 2/20)
# Epoch 89 train loss: 0.5080, val loss: 0.5987 (patience: 3/20)
# Epoch 90 train loss: 0.5079, val loss: 0.6042 (patience: 4/20)
# Epoch 91 train loss: 0.5080, val loss: 0.6040 (patience: 5/20)
# Epoch 92 train loss: 0.5115, val loss: 0.6003 (patience: 6/20)
# lr has been updated from 0.00005 to 0.00004
# Epoch 93 train loss: 0.5065, val loss: 0.5944 ✓ (new best)
# Epoch 94 train loss: 0.5032, val loss: 0.5928 ✓ (new best)
# Epoch 95 train loss: 0.5015, val loss: 0.5946 (patience: 1/20)
# Epoch 96 train loss: 0.5019, val loss: 0.5944 (patience: 2/20)
# Epoch 97 train loss: 0.5027, val loss: 0.5953 (patience: 3/20)
# Epoch 98 train loss: 0.5012, val loss: 0.5918 ✓ (new best)
# Epoch 99 train loss: 0.5002, val loss: 0.5931 (patience: 1/20)
# Epoch 100 train loss: 0.5018, val loss: 0.5929 (patience: 2/20)
# Epoch 101 train loss: 0.5018, val loss: 0.5970 (patience: 3/20)
# Epoch 102 train loss: 0.5020, val loss: 0.5926 (patience: 4/20)
# Epoch 103 train loss: 0.4997, val loss: 0.5951 (patience: 5/20)
# Epoch 104 train loss: 0.5011, val loss: 0.5905 ✓ (new best)
# Epoch 105 train loss: 0.5005, val loss: 0.5918 (patience: 1/20)
# Epoch 106 train loss: 0.5032, val loss: 0.5930 (patience: 2/20)
# Epoch 107 train loss: 0.4981, val loss: 0.5937 (patience: 3/20)
# Epoch 108 train loss: 0.5005, val loss: 0.5953 (patience: 4/20)
# Epoch 109 train loss: 0.4992, val loss: 0.5949 (patience: 5/20)
# Epoch 110 train loss: 0.4969, val loss: 0.5932 (patience: 6/20)
# lr has been updated from 0.00004 to 0.00003
# Epoch 111 train loss: 0.4937, val loss: 0.5964 (patience: 7/20)
# Epoch 112 train loss: 0.4932, val loss: 0.5949 (patience: 8/20)
# Epoch 113 train loss: 0.4899, val loss: 0.5949 (patience: 9/20)
# Epoch 114 train loss: 0.4926, val loss: 0.5943 (patience: 10/20)
# Epoch 115 train loss: 0.4884, val loss: 0.5966 (patience: 11/20)
# Epoch 116 train loss: 0.4931, val loss: 0.5957 (patience: 12/20)
# lr has been updated from 0.00003 to 0.00003
# Epoch 117 train loss: 0.4861, val loss: 0.5955 (patience: 13/20)
# Epoch 118 train loss: 0.4829, val loss: 0.5965 (patience: 14/20)
# Epoch 119 train loss: 0.4861, val loss: 0.5972 (patience: 15/20)
# Epoch 120 train loss: 0.4849, val loss: 0.5967 (patience: 16/20)
# Epoch 121 train loss: 0.4889, val loss: 0.5985 (patience: 17/20)
# Epoch 122 train loss: 0.4846, val loss: 0.5989 (patience: 18/20)
# lr has been updated from 0.00003 to 0.00002
# Epoch 123 train loss: 0.4864, val loss: 0.6018 (patience: 19/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.5905
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████| 47/47 [00:00<00:00, 555.53it/s]
# Test loss: 0.9684
# ========================================
# ==     Training commuter 1 graph      ==
# ========================================
# Epoch 1 train loss: 1.0960, val loss: 1.2241 ✓ (new best)
# Epoch 2 train loss: 0.9776, val loss: 1.3338 (patience: 1/20)
# Epoch 3 train loss: 0.9346, val loss: 1.0823 ✓ (new best)
# Epoch 4 train loss: 0.8824, val loss: 1.0923 (patience: 1/20)
# Epoch 5 train loss: 0.8602, val loss: 1.0499 ✓ (new best)
# Epoch 6 train loss: 0.8358, val loss: 0.9806 ✓ (new best)
# Epoch 7 train loss: 0.8128, val loss: 0.9668 ✓ (new best)
# Epoch 8 train loss: 0.8010, val loss: 0.9060 ✓ (new best)
# Epoch 9 train loss: 0.7844, val loss: 0.8873 ✓ (new best)
# Epoch 10 train loss: 0.7677, val loss: 0.8593 ✓ (new best)
# Epoch 11 train loss: 0.7604, val loss: 0.8798 (patience: 1/20)
# Epoch 12 train loss: 0.7496, val loss: 0.8197 ✓ (new best)
# Epoch 13 train loss: 0.7410, val loss: 0.8357 (patience: 1/20)
# Epoch 14 train loss: 0.7335, val loss: 0.8253 (patience: 2/20)
# Epoch 15 train loss: 0.7291, val loss: 0.8070 ✓ (new best)
# Epoch 16 train loss: 0.7185, val loss: 0.7966 ✓ (new best)
# Epoch 17 train loss: 0.7142, val loss: 0.7978 (patience: 1/20)
# Epoch 18 train loss: 0.7092, val loss: 0.7848 ✓ (new best)
# Epoch 19 train loss: 0.6973, val loss: 0.7797 ✓ (new best)
# Epoch 20 train loss: 0.6952, val loss: 0.7788 ✓ (new best)
# Epoch 21 train loss: 0.6917, val loss: 0.7586 ✓ (new best)
# Epoch 22 train loss: 0.6872, val loss: 0.7762 (patience: 1/20)
# Epoch 23 train loss: 0.6782, val loss: 0.7437 ✓ (new best)
# Epoch 24 train loss: 0.6758, val loss: 0.7732 (patience: 1/20)
# Epoch 25 train loss: 0.6659, val loss: 0.7529 (patience: 2/20)
# Epoch 26 train loss: 0.6621, val loss: 0.7697 (patience: 3/20)
# Epoch 27 train loss: 0.6566, val loss: 0.7722 (patience: 4/20)
# Epoch 28 train loss: 0.6518, val loss: 0.7598 (patience: 5/20)
# Epoch 29 train loss: 0.6464, val loss: 0.7697 (patience: 6/20)
# lr has been updated from 0.00010 to 0.00008
# Epoch 30 train loss: 0.6403, val loss: 0.7092 ✓ (new best)
# Epoch 31 train loss: 0.6319, val loss: 0.7158 (patience: 1/20)
# Epoch 32 train loss: 0.6304, val loss: 0.7195 (patience: 2/20)
# Epoch 33 train loss: 0.6262, val loss: 0.7225 (patience: 3/20)
# Epoch 34 train loss: 0.6183, val loss: 0.7234 (patience: 4/20)
# Epoch 35 train loss: 0.6206, val loss: 0.7349 (patience: 5/20)
# Epoch 36 train loss: 0.6204, val loss: 0.7331 (patience: 6/20)
# lr has been updated from 0.00008 to 0.00006
# Epoch 37 train loss: 0.6093, val loss: 0.6844 ✓ (new best)
# Epoch 38 train loss: 0.6027, val loss: 0.6931 (patience: 1/20)
# Epoch 39 train loss: 0.6023, val loss: 0.6872 (patience: 2/20)
# Epoch 40 train loss: 0.5999, val loss: 0.6905 (patience: 3/20)
# Epoch 41 train loss: 0.5962, val loss: 0.6888 (patience: 4/20)
# Epoch 42 train loss: 0.5946, val loss: 0.6800 ✓ (new best)
# Epoch 43 train loss: 0.5929, val loss: 0.6833 (patience: 1/20)
# Epoch 44 train loss: 0.5978, val loss: 0.6916 (patience: 2/20)
# Epoch 45 train loss: 0.5926, val loss: 0.6894 (patience: 3/20)
# Epoch 46 train loss: 0.5869, val loss: 0.6723 ✓ (new best)
# Epoch 47 train loss: 0.5899, val loss: 0.6895 (patience: 1/20)
# Epoch 48 train loss: 0.5846, val loss: 0.6797 (patience: 2/20)
# Epoch 49 train loss: 0.5815, val loss: 0.6897 (patience: 3/20)
# Epoch 50 train loss: 0.5796, val loss: 0.6700 ✓ (new best)
# Epoch 51 train loss: 0.5786, val loss: 0.6764 (patience: 1/20)
# Epoch 52 train loss: 0.5765, val loss: 0.6672 ✓ (new best)
# Epoch 53 train loss: 0.5773, val loss: 0.6643 ✓ (new best)
# Epoch 54 train loss: 0.5733, val loss: 0.6702 (patience: 1/20)
# Epoch 55 train loss: 0.5712, val loss: 0.6612 ✓ (new best)
# Epoch 56 train loss: 0.5726, val loss: 0.6579 ✓ (new best)
# Epoch 57 train loss: 0.5688, val loss: 0.6607 (patience: 1/20)
# Epoch 58 train loss: 0.5712, val loss: 0.6641 (patience: 2/20)
# Epoch 59 train loss: 0.5640, val loss: 0.6489 ✓ (new best)
# Epoch 60 train loss: 0.5618, val loss: 0.6536 (patience: 1/20)
# Epoch 61 train loss: 0.5677, val loss: 0.6560 (patience: 2/20)
# Epoch 62 train loss: 0.5624, val loss: 0.6485 ✓ (new best)
# Epoch 63 train loss: 0.5602, val loss: 0.6341 ✓ (new best)
# Epoch 64 train loss: 0.5631, val loss: 0.6530 (patience: 1/20)
# Epoch 65 train loss: 0.5563, val loss: 0.6295 ✓ (new best)
# Epoch 66 train loss: 0.5577, val loss: 0.6396 (patience: 1/20)
# Epoch 67 train loss: 0.5588, val loss: 0.6330 (patience: 2/20)
# Epoch 68 train loss: 0.5566, val loss: 0.6376 (patience: 3/20)
# Epoch 69 train loss: 0.5562, val loss: 0.6278 ✓ (new best)
# Epoch 70 train loss: 0.5531, val loss: 0.6281 (patience: 1/20)
# Epoch 71 train loss: 0.5529, val loss: 0.6241 ✓ (new best)
# Epoch 72 train loss: 0.5522, val loss: 0.6315 (patience: 1/20)
# Epoch 73 train loss: 0.5476, val loss: 0.6302 (patience: 2/20)
# Epoch 74 train loss: 0.5536, val loss: 0.6337 (patience: 3/20)
# Epoch 75 train loss: 0.5487, val loss: 0.6255 (patience: 4/20)
# Epoch 76 train loss: 0.5462, val loss: 0.6231 ✓ (new best)
# Epoch 77 train loss: 0.5446, val loss: 0.6257 (patience: 1/20)
# Epoch 78 train loss: 0.5449, val loss: 0.6100 ✓ (new best)
# Epoch 79 train loss: 0.5432, val loss: 0.6247 (patience: 1/20)
# Epoch 80 train loss: 0.5452, val loss: 0.6153 (patience: 2/20)
# Epoch 81 train loss: 0.5423, val loss: 0.6204 (patience: 3/20)
# Epoch 82 train loss: 0.5451, val loss: 0.6176 (patience: 4/20)
# Epoch 83 train loss: 0.5473, val loss: 0.6231 (patience: 5/20)
# Epoch 84 train loss: 0.5389, val loss: 0.6097 ✓ (new best)
# Epoch 85 train loss: 0.5424, val loss: 0.6083 ✓ (new best)
# Epoch 86 train loss: 0.5364, val loss: 0.6171 (patience: 1/20)
# Epoch 87 train loss: 0.5412, val loss: 0.6064 ✓ (new best)
# Epoch 88 train loss: 0.5372, val loss: 0.6202 (patience: 1/20)
# Epoch 89 train loss: 0.5379, val loss: 0.6089 (patience: 2/20)
# Epoch 90 train loss: 0.5396, val loss: 0.6128 (patience: 3/20)
# Epoch 91 train loss: 0.5380, val loss: 0.6024 ✓ (new best)
# Epoch 92 train loss: 0.5314, val loss: 0.6039 (patience: 1/20)
# Epoch 93 train loss: 0.5352, val loss: 0.6007 ✓ (new best)
# Epoch 94 train loss: 0.5343, val loss: 0.6104 (patience: 1/20)
# Epoch 95 train loss: 0.5331, val loss: 0.5968 ✓ (new best)
# Epoch 96 train loss: 0.5341, val loss: 0.6118 (patience: 1/20)
# Epoch 97 train loss: 0.5340, val loss: 0.5984 (patience: 2/20)
# Epoch 98 train loss: 0.5335, val loss: 0.6165 (patience: 3/20)
# Epoch 99 train loss: 0.5334, val loss: 0.5999 (patience: 4/20)
# Epoch 100 train loss: 0.5300, val loss: 0.6133 (patience: 5/20)
# Epoch 101 train loss: 0.5306, val loss: 0.5926 ✓ (new best)
# Epoch 102 train loss: 0.5298, val loss: 0.6184 (patience: 1/20)
# Epoch 103 train loss: 0.5310, val loss: 0.5968 (patience: 2/20)
# Epoch 104 train loss: 0.5315, val loss: 0.6047 (patience: 3/20)
# Epoch 105 train loss: 0.5288, val loss: 0.5941 (patience: 4/20)
# Epoch 106 train loss: 0.5282, val loss: 0.6102 (patience: 5/20)
# Epoch 107 train loss: 0.5265, val loss: 0.5973 (patience: 6/20)
# lr has been updated from 0.00006 to 0.00005
# Epoch 108 train loss: 0.5236, val loss: 0.5885 ✓ (new best)
# Epoch 109 train loss: 0.5185, val loss: 0.5874 ✓ (new best)
# Epoch 110 train loss: 0.5210, val loss: 0.5895 (patience: 1/20)
# Epoch 111 train loss: 0.5193, val loss: 0.5910 (patience: 2/20)
# Epoch 112 train loss: 0.5195, val loss: 0.5922 (patience: 3/20)
# Epoch 113 train loss: 0.5119, val loss: 0.5936 (patience: 4/20)
# Epoch 114 train loss: 0.5153, val loss: 0.5924 (patience: 5/20)
# Epoch 115 train loss: 0.5162, val loss: 0.5975 (patience: 6/20)
# lr has been updated from 0.00005 to 0.00004
# Epoch 116 train loss: 0.5137, val loss: 0.5902 (patience: 7/20)
# Epoch 117 train loss: 0.5089, val loss: 0.5927 (patience: 8/20)
# Epoch 118 train loss: 0.5099, val loss: 0.5886 (patience: 9/20)
# Epoch 119 train loss: 0.5059, val loss: 0.5909 (patience: 10/20)
# Epoch 120 train loss: 0.5069, val loss: 0.5877 (patience: 11/20)
# Epoch 121 train loss: 0.5069, val loss: 0.5864 ✓ (new best)
# Epoch 122 train loss: 0.5085, val loss: 0.5915 (patience: 1/20)
# Epoch 123 train loss: 0.5084, val loss: 0.5895 (patience: 2/20)
# Epoch 124 train loss: 0.5067, val loss: 0.5888 (patience: 3/20)
# Epoch 125 train loss: 0.5067, val loss: 0.5918 (patience: 4/20)
# Epoch 126 train loss: 0.5050, val loss: 0.5875 (patience: 5/20)
# Epoch 127 train loss: 0.5078, val loss: 0.5907 (patience: 6/20)
# lr has been updated from 0.00004 to 0.00003
# Epoch 128 train loss: 0.5016, val loss: 0.5930 (patience: 7/20)
# Epoch 129 train loss: 0.4994, val loss: 0.5913 (patience: 8/20)
# Epoch 130 train loss: 0.5023, val loss: 0.5919 (patience: 9/20)
# Epoch 131 train loss: 0.5017, val loss: 0.5912 (patience: 10/20)
# Epoch 132 train loss: 0.4995, val loss: 0.5901 (patience: 11/20)
# Epoch 133 train loss: 0.5028, val loss: 0.5927 (patience: 12/20)
# lr has been updated from 0.00003 to 0.00003
# Epoch 134 train loss: 0.4978, val loss: 0.5974 (patience: 13/20)
# Epoch 135 train loss: 0.4948, val loss: 0.5966 (patience: 14/20)
# Epoch 136 train loss: 0.4921, val loss: 0.5968 (patience: 15/20)
# Epoch 137 train loss: 0.4940, val loss: 0.5976 (patience: 16/20)
# Epoch 138 train loss: 0.4932, val loss: 0.5975 (patience: 17/20)
# Epoch 139 train loss: 0.4928, val loss: 0.5965 (patience: 18/20)
# lr has been updated from 0.00003 to 0.00002
# Epoch 140 train loss: 0.4933, val loss: 0.5989 (patience: 19/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.5864
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████| 47/47 [00:00<00:00, 554.72it/s]
# Test loss: 0.9695
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-10 (+5 weeks)
# berlin districts removed
# ✓ Initialized 4 RF model
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 87
#      85 rfmodel.set_global_hparams()
#      86 rfmodel.set_model_hparams()
# ---> 87 rfmodel.train()
#      88 rfmodel.forecast('test')
#      89 rfmodel.show_forecasts('test',0, show_all_horizons=True)
#
# File ~/projects/germany_gnn/src/models/shallow/node_rf.py:140, in NodeRFModel.train(self, verbose, show_loss)
#     137 model = self.models[hh]
#     139 # Train the model on the training data
# --> 140 model.fit(X_train, y_train.values.ravel())
#     142 # After training the model, validate it
#     143 y_train_pred = model.predict(X_train)
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/sklearn/utils/parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %%
from src.models.deep.gatv2 import GATv2Model
from src.models.base.persistencemodel import PersistenceModel

dl_id  = epidata_loader_basis.copy().retrieve_graph('identity_selfmax').construct_dataloaders()
dl_bn  = epidata_loader_basis.copy().retrieve_graph('boolean_neighbors_selfmean').construct_dataloaders()
dl_cm1 = epidata_loader_basis.copy().retrieve_graph('commuter_t2000_selfmean_symmetric').construct_dataloaders()
dl_cm2 = epidata_loader_basis.copy().retrieve_graph('commuter_t2000_selfmean_rowwise').construct_dataloaders()

gatv2_id = GATv2Model(dataloader= dl_id, name = 'gatv2 id graph')
gatv2_id.set_model_hparams()
gatv2_id.set_global_hparams(**global_hparams)
gatv2_id.train(2)
gatv2_id.forecast('test')

gatv2_bn = GATv2Model(dataloader= dl_bn, name = 'gatv2 bn graph')
gatv2_bn.set_model_hparams()
gatv2_bn.set_global_hparams(**global_hparams)
gatv2_bn.train(2)
gatv2_bn.forecast('test')

gatv2_cm1 = GATv2Model(dataloader= dl_cm1, name = 'gatv2 cm1 graph')
gatv2_cm1.set_model_hparams()
gatv2_cm1.set_global_hparams(**global_hparams)
gatv2_cm1.train(2)
gatv2_cm1.forecast('test')

gatv2_cm2 = GATv2Model(dataloader= dl_cm2, name = 'gatv2 cm2 graph')
gatv2_cm2.set_model_hparams()
gatv2_cm2.set_global_hparams(**global_hparams)
gatv2_cm2.train(2)
gatv2_cm2.forecast('test')

baseline = PersistenceModel(epiloader, name = 'persistence baseline')
baseline.forecast('test')
# Out:
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-17 (+4 weeks)
# berlin districts removed
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-17 (+4 weeks)
# berlin districts removed
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-17 (+4 weeks)
# berlin districts removed
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-04-17 (+4 weeks)
# berlin districts removed
# Dataloader Snapshot: GraphDataLoaderEntry(x=(400, 3, 1), y=(400, 1), edge_index=(2, 400), edge_weight=(400,))
#
# ========================================
# ==     Training gatv2 id graph     ==
# ========================================
# Epoch 1 train loss: 0.7272, val loss: 1.1883 ✓ (new best)
# Epoch 2 train loss: 0.6631, val loss: 1.0441 ✓ (new best)
# Epoch 3 train loss: 0.6396, val loss: 0.9543 ✓ (new best)
# Epoch 4 train loss: 0.6243, val loss: 0.8835 ✓ (new best)
# Epoch 5 train loss: 0.6154, val loss: 0.8147 ✓ (new best)
# Epoch 6 train loss: 0.6012, val loss: 0.7769 ✓ (new best)
# Epoch 7 train loss: 0.5979, val loss: 0.7437 ✓ (new best)
# Epoch 8 train loss: 0.5892, val loss: 0.7407 ✓ (new best)
# Epoch 9 train loss: 0.5895, val loss: 0.7285 ✓ (new best)
# Epoch 10 train loss: 0.5834, val loss: 0.7271 ✓ (new best)
# Epoch 11 train loss: 0.5822, val loss: 0.7341 (patience: 1/20)
# Epoch 12 train loss: 0.5806, val loss: 0.7327 (patience: 2/20)
# Epoch 13 train loss: 0.5800, val loss: 0.7302 (patience: 3/20)
# Epoch 14 train loss: 0.5749, val loss: 0.7296 (patience: 4/20)
# Epoch 15 train loss: 0.5737, val loss: 0.7172 ✓ (new best)
# Epoch 16 train loss: 0.5680, val loss: 0.7196 (patience: 1/20)
# Epoch 17 train loss: 0.5656, val loss: 0.7096 ✓ (new best)
# Epoch 18 train loss: 0.5677, val loss: 0.6916 ✓ (new best)
# Epoch 19 train loss: 0.5638, val loss: 0.6852 ✓ (new best)
# Epoch 20 train loss: 0.5663, val loss: 0.6809 ✓ (new best)
# Epoch 21 train loss: 0.5580, val loss: 0.6761 ✓ (new best)
# Epoch 22 train loss: 0.5596, val loss: 0.6686 ✓ (new best)
# Epoch 23 train loss: 0.5572, val loss: 0.6609 ✓ (new best)
# Epoch 24 train loss: 0.5565, val loss: 0.6452 ✓ (new best)
# Epoch 25 train loss: 0.5536, val loss: 0.6389 ✓ (new best)
# Epoch 26 train loss: 0.5507, val loss: 0.6325 ✓ (new best)
# Epoch 27 train loss: 0.5425, val loss: 0.6248 ✓ (new best)
# Epoch 28 train loss: 0.5465, val loss: 0.6150 ✓ (new best)
# Epoch 29 train loss: 0.5387, val loss: 0.6091 ✓ (new best)
# Epoch 30 train loss: 0.5368, val loss: 0.6014 ✓ (new best)
# Epoch 31 train loss: 0.5334, val loss: 0.5932 ✓ (new best)
# Epoch 32 train loss: 0.5297, val loss: 0.5865 ✓ (new best)
# Epoch 33 train loss: 0.5333, val loss: 0.5851 ✓ (new best)
# Epoch 34 train loss: 0.5247, val loss: 0.5765 ✓ (new best)
# Epoch 35 train loss: 0.5233, val loss: 0.5699 ✓ (new best)
# Epoch 36 train loss: 0.5166, val loss: 0.5632 ✓ (new best)
# Epoch 37 train loss: 0.5167, val loss: 0.5602 ✓ (new best)
# Epoch 38 train loss: 0.5118, val loss: 0.5500 ✓ (new best)
# Epoch 39 train loss: 0.5078, val loss: 0.5461 ✓ (new best)
# Epoch 40 train loss: 0.5051, val loss: 0.5395 ✓ (new best)
# Epoch 41 train loss: 0.5001, val loss: 0.5309 ✓ (new best)
# Epoch 42 train loss: 0.4986, val loss: 0.5279 ✓ (new best)
# Epoch 43 train loss: 0.4950, val loss: 0.5289 (patience: 1/20)
# Epoch 44 train loss: 0.4910, val loss: 0.5236 ✓ (new best)
# Epoch 45 train loss: 0.4839, val loss: 0.5379 (patience: 1/20)
# Epoch 46 train loss: 0.4867, val loss: 0.5361 (patience: 2/20)
# Epoch 47 train loss: 0.4812, val loss: 0.5382 (patience: 3/20)
# Epoch 48 train loss: 0.4777, val loss: 0.5411 (patience: 4/20)
# Epoch 49 train loss: 0.4725, val loss: 0.5485 (patience: 5/20)
# Epoch 50 train loss: 0.4739, val loss: 0.5474 (patience: 6/20)
# Epoch 51 train loss: 0.4684, val loss: 0.5408 (patience: 7/20)
# Epoch 52 train loss: 0.4658, val loss: 0.5406 (patience: 8/20)
# Epoch 53 train loss: 0.4524, val loss: 0.5655 (patience: 9/20)
# Epoch 54 train loss: 0.4460, val loss: 0.5708 (patience: 10/20)
# Epoch 55 train loss: 0.4437, val loss: 0.5715 (patience: 11/20)
# Epoch 56 train loss: 0.4440, val loss: 0.5686 (patience: 12/20)
# Epoch 57 train loss: 0.4433, val loss: 0.5688 (patience: 13/20)
# Epoch 58 train loss: 0.4396, val loss: 0.5660 (patience: 14/20)
# Epoch 59 train loss: 0.4399, val loss: 0.5649 (patience: 15/20)
# Epoch 60 train loss: 0.4437, val loss: 0.5671 (patience: 16/20)
# Epoch 61 train loss: 0.4290, val loss: 0.5905 (patience: 17/20)
# Epoch 62 train loss: 0.4298, val loss: 0.5942 (patience: 18/20)
# Epoch 63 train loss: 0.4287, val loss: 0.5987 (patience: 19/20)
# Epoch 64 train loss: 0.4248, val loss: 0.6021 (patience: 20/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.5236
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 564.63it/s]
# Test loss: 0.9382
# Dataloader Snapshot: GraphDataLoaderEntry(x=(400, 3, 1), y=(400, 1), edge_index=(2, 2488), edge_weight=(2488,))
#
# ========================================
# ==     Training gatv2 bn graph     ==
# ========================================
# Epoch 1 train loss: 0.7077, val loss: 1.1011 ✓ (new best)
# Epoch 2 train loss: 0.6468, val loss: 0.9485 ✓ (new best)
# Epoch 3 train loss: 0.6192, val loss: 0.8492 ✓ (new best)
# Epoch 4 train loss: 0.5967, val loss: 0.7860 ✓ (new best)
# Epoch 5 train loss: 0.5858, val loss: 0.7458 ✓ (new best)
# Epoch 6 train loss: 0.5758, val loss: 0.7260 ✓ (new best)
# Epoch 7 train loss: 0.5742, val loss: 0.7094 ✓ (new best)
# Epoch 8 train loss: 0.5685, val loss: 0.6980 ✓ (new best)
# Epoch 9 train loss: 0.5627, val loss: 0.6951 ✓ (new best)
# Epoch 10 train loss: 0.5598, val loss: 0.6881 ✓ (new best)
# Epoch 11 train loss: 0.5543, val loss: 0.6839 ✓ (new best)
# Epoch 12 train loss: 0.5492, val loss: 0.6809 ✓ (new best)
# Epoch 13 train loss: 0.5481, val loss: 0.6797 ✓ (new best)
# Epoch 14 train loss: 0.5435, val loss: 0.6756 ✓ (new best)
# Epoch 15 train loss: 0.5386, val loss: 0.6747 ✓ (new best)
# Epoch 16 train loss: 0.5327, val loss: 0.6715 ✓ (new best)
# Epoch 17 train loss: 0.5304, val loss: 0.6677 ✓ (new best)
# Epoch 18 train loss: 0.5226, val loss: 0.6621 ✓ (new best)
# Epoch 19 train loss: 0.5185, val loss: 0.6641 (patience: 1/20)
# Epoch 20 train loss: 0.5177, val loss: 0.6581 ✓ (new best)
# Epoch 21 train loss: 0.5174, val loss: 0.6586 (patience: 1/20)
# Epoch 22 train loss: 0.5131, val loss: 0.6598 (patience: 2/20)
# Epoch 23 train loss: 0.5072, val loss: 0.6624 (patience: 3/20)
# Epoch 24 train loss: 0.5018, val loss: 0.6607 (patience: 4/20)
# Epoch 25 train loss: 0.5009, val loss: 0.6546 ✓ (new best)
# Epoch 26 train loss: 0.4946, val loss: 0.6479 ✓ (new best)
# Epoch 27 train loss: 0.4906, val loss: 0.6400 ✓ (new best)
# Epoch 28 train loss: 0.4845, val loss: 0.6223 ✓ (new best)
# Epoch 29 train loss: 0.4757, val loss: 0.6149 ✓ (new best)
# Epoch 30 train loss: 0.4732, val loss: 0.6079 ✓ (new best)
# Epoch 31 train loss: 0.4658, val loss: 0.5911 ✓ (new best)
# Epoch 32 train loss: 0.4597, val loss: 0.5816 ✓ (new best)
# Epoch 33 train loss: 0.4561, val loss: 0.5681 ✓ (new best)
# Epoch 34 train loss: 0.4531, val loss: 0.5565 ✓ (new best)
# Epoch 35 train loss: 0.4480, val loss: 0.5629 (patience: 1/20)
# Epoch 36 train loss: 0.4503, val loss: 0.5451 ✓ (new best)
# Epoch 37 train loss: 0.4427, val loss: 0.5338 ✓ (new best)
# Epoch 38 train loss: 0.4415, val loss: 0.5267 ✓ (new best)
# Epoch 39 train loss: 0.4437, val loss: 0.5199 ✓ (new best)
# Epoch 40 train loss: 0.4443, val loss: 0.5199 (patience: 1/20)
# Epoch 41 train loss: 0.4367, val loss: 0.5127 ✓ (new best)
# Epoch 42 train loss: 0.4355, val loss: 0.5077 ✓ (new best)
# Epoch 43 train loss: 0.4400, val loss: 0.4997 ✓ (new best)
# Epoch 44 train loss: 0.4306, val loss: 0.5020 (patience: 1/20)
# Epoch 45 train loss: 0.4337, val loss: 0.4959 ✓ (new best)
# Epoch 46 train loss: 0.4344, val loss: 0.4918 ✓ (new best)
# Epoch 47 train loss: 0.4335, val loss: 0.4913 ✓ (new best)
# Epoch 48 train loss: 0.4278, val loss: 0.4884 ✓ (new best)
# Epoch 49 train loss: 0.4291, val loss: 0.4860 ✓ (new best)
# Epoch 50 train loss: 0.4263, val loss: 0.4870 (patience: 1/20)
# Epoch 51 train loss: 0.4279, val loss: 0.4836 ✓ (new best)
# Epoch 52 train loss: 0.4250, val loss: 0.4843 (patience: 1/20)
# Epoch 53 train loss: 0.4281, val loss: 0.4786 ✓ (new best)
# Epoch 54 train loss: 0.4384, val loss: 0.4835 (patience: 1/20)
# Epoch 55 train loss: 0.4220, val loss: 0.4775 ✓ (new best)
# Epoch 56 train loss: 0.4209, val loss: 0.4778 (patience: 1/20)
# Epoch 57 train loss: 0.4192, val loss: 0.4704 ✓ (new best)
# Epoch 58 train loss: 0.4193, val loss: 0.4730 (patience: 1/20)
# Epoch 59 train loss: 0.4269, val loss: 0.4697 ✓ (new best)
# Epoch 60 train loss: 0.4275, val loss: 0.4734 (patience: 1/20)
# Epoch 61 train loss: 0.4194, val loss: 0.4683 ✓ (new best)
# Epoch 62 train loss: 0.4173, val loss: 0.4706 (patience: 1/20)
# Epoch 63 train loss: 0.4208, val loss: 0.4675 ✓ (new best)
# Epoch 64 train loss: 0.4143, val loss: 0.4693 (patience: 1/20)
# Epoch 65 train loss: 0.4140, val loss: 0.4605 ✓ (new best)
# Epoch 66 train loss: 0.4194, val loss: 0.4675 (patience: 1/20)
# Epoch 67 train loss: 0.4129, val loss: 0.4609 (patience: 2/20)
# Epoch 68 train loss: 0.4163, val loss: 0.4675 (patience: 3/20)
# Epoch 69 train loss: 0.4129, val loss: 0.4533 ✓ (new best)
# Epoch 70 train loss: 0.4193, val loss: 0.4676 (patience: 1/20)
# Epoch 71 train loss: 0.4084, val loss: 0.4607 (patience: 2/20)
# Epoch 72 train loss: 0.4124, val loss: 0.4672 (patience: 3/20)
# Epoch 73 train loss: 0.4105, val loss: 0.4585 (patience: 4/20)
# Epoch 74 train loss: 0.4120, val loss: 0.4693 (patience: 5/20)
# Epoch 75 train loss: 0.4155, val loss: 0.4566 (patience: 6/20)
# Epoch 76 train loss: 0.4288, val loss: 0.4722 (patience: 7/20)
# Epoch 77 train loss: 0.4088, val loss: 0.4655 (patience: 8/20)
# Epoch 78 train loss: 0.3910, val loss: 0.4820 (patience: 9/20)
# Epoch 79 train loss: 0.3900, val loss: 0.4825 (patience: 10/20)
# Epoch 80 train loss: 0.3882, val loss: 0.4806 (patience: 11/20)
# Epoch 81 train loss: 0.3875, val loss: 0.4828 (patience: 12/20)
# Epoch 82 train loss: 0.3889, val loss: 0.4839 (patience: 13/20)
# Epoch 83 train loss: 0.3848, val loss: 0.4791 (patience: 14/20)
# Epoch 84 train loss: 0.3878, val loss: 0.4806 (patience: 15/20)
# Epoch 85 train loss: 0.3875, val loss: 0.4784 (patience: 16/20)
# Epoch 86 train loss: 0.3763, val loss: 0.4923 (patience: 17/20)
# Epoch 87 train loss: 0.3777, val loss: 0.4927 (patience: 18/20)
# Epoch 88 train loss: 0.3752, val loss: 0.4949 (patience: 19/20)
# Epoch 89 train loss: 0.3744, val loss: 0.4942 (patience: 20/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.4533
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 540.24it/s]
# Test loss: 0.7378
# Dataloader Snapshot: GraphDataLoaderEntry(x=(400, 3, 1), y=(400, 1), edge_index=(2, 1754), edge_weight=(1754,))
#
# ========================================
# ==     Training gatv2 cm1 graph     ==
# ========================================
# Epoch 1 train loss: 0.7151, val loss: 1.1376 ✓ (new best)
# Epoch 2 train loss: 0.6615, val loss: 1.0003 ✓ (new best)
# Epoch 3 train loss: 0.6321, val loss: 0.9032 ✓ (new best)
# Epoch 4 train loss: 0.6168, val loss: 0.8401 ✓ (new best)
# Epoch 5 train loss: 0.6054, val loss: 0.8025 ✓ (new best)
# Epoch 6 train loss: 0.6003, val loss: 0.7727 ✓ (new best)
# Epoch 7 train loss: 0.5910, val loss: 0.7510 ✓ (new best)
# Epoch 8 train loss: 0.5852, val loss: 0.7321 ✓ (new best)
# Epoch 9 train loss: 0.5832, val loss: 0.7213 ✓ (new best)
# Epoch 10 train loss: 0.5783, val loss: 0.7151 ✓ (new best)
# Epoch 11 train loss: 0.5742, val loss: 0.7033 ✓ (new best)
# Epoch 12 train loss: 0.5674, val loss: 0.6980 ✓ (new best)
# Epoch 13 train loss: 0.5657, val loss: 0.6922 ✓ (new best)
# Epoch 14 train loss: 0.5592, val loss: 0.6837 ✓ (new best)
# Epoch 15 train loss: 0.5532, val loss: 0.6710 ✓ (new best)
# Epoch 16 train loss: 0.5486, val loss: 0.6598 ✓ (new best)
# Epoch 17 train loss: 0.5396, val loss: 0.6538 ✓ (new best)
# Epoch 18 train loss: 0.5401, val loss: 0.6482 ✓ (new best)
# Epoch 19 train loss: 0.5348, val loss: 0.6441 ✓ (new best)
# Epoch 20 train loss: 0.5353, val loss: 0.6476 (patience: 1/20)
# Epoch 21 train loss: 0.5316, val loss: 0.6483 (patience: 2/20)
# Epoch 22 train loss: 0.5328, val loss: 0.6474 (patience: 3/20)
# Epoch 23 train loss: 0.5286, val loss: 0.6492 (patience: 4/20)
# Epoch 24 train loss: 0.5245, val loss: 0.6505 (patience: 5/20)
# Epoch 25 train loss: 0.5262, val loss: 0.6536 (patience: 6/20)
# Epoch 26 train loss: 0.5185, val loss: 0.6383 ✓ (new best)
# Epoch 27 train loss: 0.5178, val loss: 0.6417 (patience: 1/20)
# Epoch 28 train loss: 0.5142, val loss: 0.6316 ✓ (new best)
# Epoch 29 train loss: 0.5105, val loss: 0.6212 ✓ (new best)
# Epoch 30 train loss: 0.5076, val loss: 0.6061 ✓ (new best)
# Epoch 31 train loss: 0.5013, val loss: 0.5928 ✓ (new best)
# Epoch 32 train loss: 0.4961, val loss: 0.5775 ✓ (new best)
# Epoch 33 train loss: 0.4913, val loss: 0.5589 ✓ (new best)
# Epoch 34 train loss: 0.4824, val loss: 0.5432 ✓ (new best)
# Epoch 35 train loss: 0.4770, val loss: 0.5290 ✓ (new best)
# Epoch 36 train loss: 0.4730, val loss: 0.5261 ✓ (new best)
# Epoch 37 train loss: 0.4698, val loss: 0.5115 ✓ (new best)
# Epoch 38 train loss: 0.4733, val loss: 0.5070 ✓ (new best)
# Epoch 39 train loss: 0.4650, val loss: 0.5072 (patience: 1/20)
# Epoch 40 train loss: 0.4539, val loss: 0.4935 ✓ (new best)
# Epoch 41 train loss: 0.4607, val loss: 0.4992 (patience: 1/20)
# Epoch 42 train loss: 0.4668, val loss: 0.4964 (patience: 2/20)
# Epoch 43 train loss: 0.4486, val loss: 0.4827 ✓ (new best)
# Epoch 44 train loss: 0.4445, val loss: 0.4888 (patience: 1/20)
# Epoch 45 train loss: 0.4527, val loss: 0.4825 ✓ (new best)
# Epoch 46 train loss: 0.4398, val loss: 0.4783 ✓ (new best)
# Epoch 47 train loss: 0.4461, val loss: 0.4746 ✓ (new best)
# Epoch 48 train loss: 0.4481, val loss: 0.4795 (patience: 1/20)
# Epoch 49 train loss: 0.4363, val loss: 0.4750 (patience: 2/20)
# Epoch 50 train loss: 0.4374, val loss: 0.4681 ✓ (new best)
# Epoch 51 train loss: 0.4393, val loss: 0.4720 (patience: 1/20)
# Epoch 52 train loss: 0.4341, val loss: 0.4658 ✓ (new best)
# Epoch 53 train loss: 0.4343, val loss: 0.4745 (patience: 1/20)
# Epoch 54 train loss: 0.4322, val loss: 0.4682 (patience: 2/20)
# Epoch 55 train loss: 0.4327, val loss: 0.4632 ✓ (new best)
# Epoch 56 train loss: 0.4363, val loss: 0.4714 (patience: 1/20)
# Epoch 57 train loss: 0.4263, val loss: 0.4701 (patience: 2/20)
# Epoch 58 train loss: 0.4274, val loss: 0.4739 (patience: 3/20)
# Epoch 59 train loss: 0.4246, val loss: 0.4683 (patience: 4/20)
# Epoch 60 train loss: 0.4317, val loss: 0.4707 (patience: 5/20)
# Epoch 61 train loss: 0.4239, val loss: 0.4665 (patience: 6/20)
# Epoch 62 train loss: 0.4212, val loss: 0.4683 (patience: 7/20)
# Epoch 63 train loss: 0.4179, val loss: 0.4667 (patience: 8/20)
# Epoch 64 train loss: 0.4080, val loss: 0.4929 (patience: 9/20)
# Epoch 65 train loss: 0.3997, val loss: 0.4905 (patience: 10/20)
# Epoch 66 train loss: 0.3969, val loss: 0.4885 (patience: 11/20)
# Epoch 67 train loss: 0.3996, val loss: 0.4898 (patience: 12/20)
# Epoch 68 train loss: 0.4001, val loss: 0.4889 (patience: 13/20)
# Epoch 69 train loss: 0.4000, val loss: 0.4866 (patience: 14/20)
# Epoch 70 train loss: 0.3994, val loss: 0.4868 (patience: 15/20)
# Epoch 71 train loss: 0.3968, val loss: 0.4862 (patience: 16/20)
# Epoch 72 train loss: 0.3880, val loss: 0.5033 (patience: 17/20)
# Epoch 73 train loss: 0.3897, val loss: 0.5082 (patience: 18/20)
# Epoch 74 train loss: 0.3867, val loss: 0.5099 (patience: 19/20)
# Epoch 75 train loss: 0.3864, val loss: 0.5098 (patience: 20/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.4632
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 560.59it/s]
# Test loss: 0.7665
# Dataloader Snapshot: GraphDataLoaderEntry(x=(400, 3, 1), y=(400, 1), edge_index=(2, 1754), edge_weight=(1754,))
#
# ========================================
# ==     Training gatv2 cm2 graph     ==
# ========================================
# Epoch 1 train loss: 0.7126, val loss: 1.1604 ✓ (new best)
# Epoch 2 train loss: 0.6598, val loss: 1.0062 ✓ (new best)
# Epoch 3 train loss: 0.6267, val loss: 0.9186 ✓ (new best)
# Epoch 4 train loss: 0.6137, val loss: 0.8517 ✓ (new best)
# Epoch 5 train loss: 0.6023, val loss: 0.8061 ✓ (new best)
# Epoch 6 train loss: 0.5922, val loss: 0.7745 ✓ (new best)
# Epoch 7 train loss: 0.5861, val loss: 0.7512 ✓ (new best)
# Epoch 8 train loss: 0.5800, val loss: 0.7278 ✓ (new best)
# Epoch 9 train loss: 0.5769, val loss: 0.7191 ✓ (new best)
# Epoch 10 train loss: 0.5719, val loss: 0.7124 ✓ (new best)
# Epoch 11 train loss: 0.5683, val loss: 0.7057 ✓ (new best)
# Epoch 12 train loss: 0.5612, val loss: 0.6982 ✓ (new best)
# Epoch 13 train loss: 0.5572, val loss: 0.6912 ✓ (new best)
# Epoch 14 train loss: 0.5542, val loss: 0.6883 ✓ (new best)
# Epoch 15 train loss: 0.5482, val loss: 0.6826 ✓ (new best)
# Epoch 16 train loss: 0.5411, val loss: 0.6768 ✓ (new best)
# Epoch 17 train loss: 0.5412, val loss: 0.6716 ✓ (new best)
# Epoch 18 train loss: 0.5347, val loss: 0.6613 ✓ (new best)
# Epoch 19 train loss: 0.5292, val loss: 0.6552 ✓ (new best)
# Epoch 20 train loss: 0.5210, val loss: 0.6409 ✓ (new best)
# Epoch 21 train loss: 0.5170, val loss: 0.6341 ✓ (new best)
# Epoch 22 train loss: 0.5124, val loss: 0.6292 ✓ (new best)
# Epoch 23 train loss: 0.5093, val loss: 0.6228 ✓ (new best)
# Epoch 24 train loss: 0.5033, val loss: 0.6091 ✓ (new best)
# Epoch 25 train loss: 0.4989, val loss: 0.6003 ✓ (new best)
# Epoch 26 train loss: 0.4908, val loss: 0.5955 ✓ (new best)
# Epoch 27 train loss: 0.4904, val loss: 0.5850 ✓ (new best)
# Epoch 28 train loss: 0.4834, val loss: 0.5780 ✓ (new best)
# Epoch 29 train loss: 0.4809, val loss: 0.5660 ✓ (new best)
# Epoch 30 train loss: 0.4766, val loss: 0.5543 ✓ (new best)
# Epoch 31 train loss: 0.4703, val loss: 0.5407 ✓ (new best)
# Epoch 32 train loss: 0.4716, val loss: 0.5360 ✓ (new best)
# Epoch 33 train loss: 0.4689, val loss: 0.5261 ✓ (new best)
# Epoch 34 train loss: 0.4626, val loss: 0.5158 ✓ (new best)
# Epoch 35 train loss: 0.4627, val loss: 0.5113 ✓ (new best)
# Epoch 36 train loss: 0.4571, val loss: 0.5028 ✓ (new best)
# Epoch 37 train loss: 0.4522, val loss: 0.4941 ✓ (new best)
# Epoch 38 train loss: 0.4581, val loss: 0.4969 (patience: 1/20)
# Epoch 39 train loss: 0.4472, val loss: 0.4895 ✓ (new best)
# Epoch 40 train loss: 0.4509, val loss: 0.4835 ✓ (new best)
# Epoch 41 train loss: 0.4468, val loss: 0.4818 ✓ (new best)
# Epoch 42 train loss: 0.4456, val loss: 0.4802 ✓ (new best)
# Epoch 43 train loss: 0.4405, val loss: 0.4763 ✓ (new best)
# Epoch 44 train loss: 0.4369, val loss: 0.4735 ✓ (new best)
# Epoch 45 train loss: 0.4395, val loss: 0.4736 (patience: 1/20)
# Epoch 46 train loss: 0.4414, val loss: 0.4705 ✓ (new best)
# Epoch 47 train loss: 0.4376, val loss: 0.4693 ✓ (new best)
# Epoch 48 train loss: 0.4399, val loss: 0.4700 (patience: 1/20)
# Epoch 49 train loss: 0.4427, val loss: 0.4693 (patience: 2/20)
# Epoch 50 train loss: 0.4339, val loss: 0.4686 ✓ (new best)
# Epoch 51 train loss: 0.4364, val loss: 0.4711 (patience: 1/20)
# Epoch 52 train loss: 0.4280, val loss: 0.4637 ✓ (new best)
# Epoch 53 train loss: 0.4340, val loss: 0.4605 ✓ (new best)
# Epoch 54 train loss: 0.4279, val loss: 0.4654 (patience: 1/20)
# Epoch 55 train loss: 0.4314, val loss: 0.4609 (patience: 2/20)
# Epoch 56 train loss: 0.4309, val loss: 0.4618 (patience: 3/20)
# Epoch 57 train loss: 0.4284, val loss: 0.4603 ✓ (new best)
# Epoch 58 train loss: 0.4255, val loss: 0.4576 ✓ (new best)
# Epoch 59 train loss: 0.4273, val loss: 0.4611 (patience: 1/20)
# Epoch 60 train loss: 0.4237, val loss: 0.4587 (patience: 2/20)
# Epoch 61 train loss: 0.4186, val loss: 0.4559 ✓ (new best)
# Epoch 62 train loss: 0.4242, val loss: 0.4586 (patience: 1/20)
# Epoch 63 train loss: 0.4180, val loss: 0.4586 (patience: 2/20)
# Epoch 64 train loss: 0.4205, val loss: 0.4558 ✓ (new best)
# Epoch 65 train loss: 0.4197, val loss: 0.4606 (patience: 1/20)
# Epoch 66 train loss: 0.4159, val loss: 0.4574 (patience: 2/20)
# Epoch 67 train loss: 0.4137, val loss: 0.4552 ✓ (new best)
# Epoch 68 train loss: 0.4188, val loss: 0.4594 (patience: 1/20)
# Epoch 69 train loss: 0.4132, val loss: 0.4592 (patience: 2/20)
# Epoch 70 train loss: 0.4162, val loss: 0.4591 (patience: 3/20)
# Epoch 71 train loss: 0.4154, val loss: 0.4592 (patience: 4/20)
# Epoch 72 train loss: 0.4153, val loss: 0.4592 (patience: 5/20)
# Epoch 73 train loss: 0.4110, val loss: 0.4619 (patience: 6/20)
# Epoch 74 train loss: 0.4100, val loss: 0.4565 (patience: 7/20)
# Epoch 75 train loss: 0.4177, val loss: 0.4631 (patience: 8/20)
# Epoch 76 train loss: 0.4018, val loss: 0.4882 (patience: 9/20)
# Epoch 77 train loss: 0.3928, val loss: 0.4888 (patience: 10/20)
# Epoch 78 train loss: 0.3921, val loss: 0.4877 (patience: 11/20)
# Epoch 79 train loss: 0.3898, val loss: 0.4854 (patience: 12/20)
# Epoch 80 train loss: 0.3908, val loss: 0.4841 (patience: 13/20)
# Epoch 81 train loss: 0.3892, val loss: 0.4832 (patience: 14/20)
# Epoch 82 train loss: 0.3914, val loss: 0.4836 (patience: 15/20)
# Epoch 83 train loss: 0.3901, val loss: 0.4836 (patience: 16/20)
# Epoch 84 train loss: 0.3832, val loss: 0.5004 (patience: 17/20)
# Epoch 85 train loss: 0.3794, val loss: 0.5058 (patience: 18/20)
# Epoch 86 train loss: 0.3751, val loss: 0.5058 (patience: 19/20)
# Epoch 87 train loss: 0.3798, val loss: 0.5051 (patience: 20/20)
# Early stopping: Validation loss hasn't improved for 20 epochs
# Restored model from best validation loss: 0.4552
# Forecasting test: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 48/48 [00:00<00:00, 559.56it/s]
# Test loss: 0.7447
# PersistenceModel(name='persistence baseline')

# %%
from src.evaluation import Evaluator
evaluation = Evaluator([baseline, gatv2_id, gatv2_bn, gatv2_cm1, gatv2_cm2], horizon_leadtime=horizon_leadtime)
evaluation.add_evaluation()
evaluation.plot_metric('rmse',      plot_type='violin')
evaluation.plot_metric('ccc',       plot_type='violin')
evaluation.plot_metric('corr',      plot_type='violin')
evaluation.plot_metric('lag_corr',  plot_type='violin')
# Out:
# Evaluator of ['persistence baseline', 'gatv2 id graph', 'gatv2 bn graph', 'gatv2 cm1 graph', 'gatv2 cm2 graph']

# %%
# gatv2_cm2.forecast('train')
gatv2_cm2.show_forecasts('train', 223, timeframe = ['2013-01-01','2017-01-01'])
# Out:
# (<Figure size 1600x1000 with 2 Axes>,
#  array([<Axes: title={'center': 'National aggregation of incidence'}, ylabel='incidence'>,
#         <Axes: title={'center': 'predictions node: 223'}, ylabel='incidence'>],
#        dtype=object))
