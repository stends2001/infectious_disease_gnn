# %%
from src.utils import get_data_env
from src.dataloading import EpiConfig, DataOrchestrator, ShallowDataLoaderManager, GraphDataLoaderManager, DeepDataLoaderManager, BaseLineDataLoaderManager
from src.models import ConstantModel, PersistenceModel, ClimateologyModel, NodeLSTMModel, NodeGRUModel, GATv2Model

# get data
disease_name    = 'influenza'
nuts_level      = 'nuts3'
min_date        = '2011-06-15'
max_date        = '2020-06-01'
split_trainval  = '2018-06-01'
split_valtest   = '2019-06-01'
split_berlin    = False

horizon_size    = 1
horizon_leadtime= 3
sequence_length = 4
lag_num         = 1

config = EpiConfig(
    disease             = disease_name,
    data_env_dir        = get_data_env(),
    date_range          = (min_date, max_date),
    horizon_size        = horizon_size,
    sequence_length     = sequence_length,
    horizon_leadtime    = horizon_leadtime,
    lag_num             = lag_num,
    nuts_level          = nuts_level,
    log_transform       = ['incidence'],
    split_berlin        = split_berlin,
    include_population  = False,
    split_trainval      = split_trainval, 
    split_valtest       = split_valtest,
    target_column       = 'incidence',
    lag_column          = 'incidence',  
    verbose             = 0  
    )    

data_orchestrator = (DataOrchestrator(config)
                        .load_raw()
                        .harmonize_raw()
                        .process_data()
                        .build_features()
                        .normalize()
                        .finalize()
                        )

sl = BaseLineDataLoaderManager(data_orchestrator)
dl = DeepDataLoaderManager(data_orchestrator).construct_dataloaders()

gl1 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('identity_graph').construct_dataloaders()
gl2 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('geographical_neighbors1').construct_dataloaders()
gl3 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('static_commuter24_1').construct_dataloaders()

# %%
import torch 
import torch.nn as nn

class MinimalGRURegressor(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, output_dim: int, num_layers= int):
        super().__init__()
        self.gru = nn.GRU(
            input_size  = input_dim,
            hidden_size = hidden_dim,
            num_layers  = num_layers,
            batch_first = True
        )
        self.gru_out_norm = nn.LayerNorm(hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, X: torch.Tensor):
        # X: [nodes, seq_len, features]
        n = X.shape[0]
        h0 = torch.zeros(self.gru.num_layers, n, self.gru.hidden_size, device=X.device)
        _, new_hidden = self.gru(X, h0)

        
        ht_gru = self.gru_out_norm(new_hidden[-1])
        return self.fc(ht_gru)   # [n, output_dim]
    
import torch
import torch.nn as nn
from torch_geometric.nn import GATv2Conv
import torch.nn.functional as F

class GRU_GATv2_Regressor(nn.Module):
    def __init__(self, input_dim: int, hidden_dim: int, gat_hidden_dim: int,
                 output_dim: int, num_layers=2, gat_heads=2):
        super().__init__()

        # GRU module
        self.gru = nn.GRU(
            input_size=input_dim,
            hidden_size=hidden_dim,
            num_layers=num_layers,
            batch_first=True
        )
        self.gru_out_norm = nn.LayerNorm(hidden_dim)

        # GATv2 module
        self.gat1 = GATv2Conv(hidden_dim, gat_hidden_dim, heads=gat_heads, concat=True)
        self.gat2 = GATv2Conv(gat_hidden_dim * gat_heads, gat_hidden_dim, heads=gat_heads, concat=True)

        # Final output layer
        self.fc = nn.Linear(gat_hidden_dim * gat_heads + hidden_dim, output_dim)  # concat ht_gru as skip connection

    def forward(self, X: torch.Tensor, edge_index: torch.Tensor):
        """
        X: [num_nodes, seq_len, features] 
        edge_index: [2, num_edges], standard PyG edge_index
        """
        n = X.shape[0]
        device = X.device

        # GRU forward
        h0 = torch.zeros(self.gru.num_layers, n, self.gru.hidden_size, device=device)
        _, new_hidden = self.gru(X, h0)
        ht_gru = self.gru_out_norm(new_hidden[-1])  # [n, hidden_dim]

        # GATv2 forward
        h = F.relu(self.gat1(ht_gru, edge_index))
        h = F.relu(self.gat2(h, edge_index))

        # Concatenate GRU embedding (skip connection)
        h_cat = torch.cat([h, ht_gru], dim=-1)

        # Final output
        out = self.fc(h_cat)  # [n, output_dim]
        return out

# %%
import torch
from torch import optim
from tqdm import tqdm

trainingloader  = gl1.dataloader_collection.train
valloader       = gl1.dataloader_collection.val
testloader      = gl1.dataloader_collection.test

from src.utils.textformatting import checkmark
# data
n            = 400
f            = 3
d            = 4

# model
hidden_dim_gru   = 256
hidden_dim_gat   = 256
num_layers   = 2
patience = 15
epochs = 500
delta = 0.0005

device = 'cuda' if torch.cuda.is_available() else 'cpu'

model1 = GRU_GATv2_Regressor(input_dim=f, hidden_dim=hidden_dim_gru, gat_hidden_dim=hidden_dim_gat, output_dim=1, num_layers=2).to(device)
optimizer = optim.Adam(model1.parameters(), lr=1e-5)
criterion = nn.MSELoss()

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=5,
    min_lr=1e-7
)

patience_counter = 0
best_val_loss = 1e6

for epoch in range(epochs):

    # TRAINING PHASE
    model1.train()
    training_loss = 0.0
    for deepdata in trainingloader:
        X_t = deepdata.x.to(device)  # [nodes, features, seq_len]
        y_t = deepdata.y.to(device)  # [nodes, 1]
        e_i = deepdata.edge_index.to(device)

        X_t = X_t.permute(0, 2, 1)  # [nodes, seq_len, features]

        optimizer.zero_grad()
        y_pred = model1(X_t, e_i)          # [nodes, output_dim]
        loss = criterion(y_pred, y_t)
        loss.backward()
        optimizer.step()

        training_loss += loss.item()# * X_t.size(0)

    # VALIDATION PHASE
    model1.eval()
    validation_loss = 0
    with torch.no_grad():
        for deepdata in valloader:
            X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
            y_t = deepdata.y.to(device)
            e_i = deepdata.edge_index.to(device)            

            X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
            y_pred = model1(X_t, e_i)                  # [nodes, output_dim]
            loss = criterion(y_pred, y_t)
            validation_loss += loss.item()

    training_loss  = training_loss / len(trainingloader)
    validation_loss= validation_loss / len(valloader)

    val_improved = validation_loss <(best_val_loss - delta)
    update = f"Epoch {epoch+1} training-Loss: {training_loss:.4f} validation-Loss {validation_loss:.4f}"
    # if so => save best model
    if val_improved:
        best_val_loss   = validation_loss
        patience_counter= 0
        best_model_state= model1.state_dict().copy()  
        update += checkmark
    else:
        patience_counter += 1       

    if patience_counter > patience:
        print('patience clompleted. Aborting training')
        break

       
    scheduler.step(validation_loss)
    print(update)

model1.load_state_dict(best_model_state)

import torch
import matplotlib.pyplot as plt
import seaborn as sns

node_idx = 15  # the node you’re tracking

model1.eval()
node_preds = []

with torch.no_grad():
    for deepdata in testloader:
        X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
        e_i = deepdata.edge_index.to(device)        
        X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
        y_pred = model1(X_t,e_i)                  # [nodes, output_dim]
        node_preds.append(y_pred[node_idx].cpu().item())

# Ground truth for this node
node_gt = [deepdata.y[node_idx].item() for deepdata in testloader]

# Plot
sns.lineplot(node_gt, label='GT')
sns.lineplot(node_preds, label='Pred')
plt.xlabel('Timepoint / validation window index')
plt.ylabel('Value')
plt.title(f'Node {node_idx} predictions vs ground truth')
plt.legend()
# plt.xlim(700,800)
plt.show()
# Out:
# Epoch 1 training-Loss: 0.6940 validation-Loss 1.0329✓
# Epoch 2 training-Loss: 0.6023 validation-Loss 0.8992✓
# Epoch 3 training-Loss: 0.5532 validation-Loss 0.7864✓
# Epoch 4 training-Loss: 0.5186 validation-Loss 0.6960✓
# Epoch 5 training-Loss: 0.4916 validation-Loss 0.6262✓
# Epoch 6 training-Loss: 0.4706 validation-Loss 0.5714✓
# Epoch 7 training-Loss: 0.4539 validation-Loss 0.5306✓
# Epoch 8 training-Loss: 0.4410 validation-Loss 0.5000✓
# Epoch 9 training-Loss: 0.4309 validation-Loss 0.4769✓
# Epoch 10 training-Loss: 0.4232 validation-Loss 0.4588✓
# Epoch 11 training-Loss: 0.4165 validation-Loss 0.4447✓
# Epoch 12 training-Loss: 0.4111 validation-Loss 0.4329✓
# Epoch 13 training-Loss: 0.4062 validation-Loss 0.4227✓
# Epoch 14 training-Loss: 0.4023 validation-Loss 0.4138✓
# Epoch 15 training-Loss: 0.3988 validation-Loss 0.4069✓
# Epoch 16 training-Loss: 0.3955 validation-Loss 0.4004✓
# Epoch 17 training-Loss: 0.3928 validation-Loss 0.3957✓
# Epoch 18 training-Loss: 0.3902 validation-Loss 0.3903✓
# Epoch 19 training-Loss: 0.3879 validation-Loss 0.3866✓
# Epoch 20 training-Loss: 0.3854 validation-Loss 0.3825✓
# Epoch 21 training-Loss: 0.3832 validation-Loss 0.3799✓
# Epoch 22 training-Loss: 0.3815 validation-Loss 0.3762✓
# Epoch 23 training-Loss: 0.3794 validation-Loss 0.3741✓
# Epoch 24 training-Loss: 0.3777 validation-Loss 0.3718✓
# Epoch 25 training-Loss: 0.3762 validation-Loss 0.3701✓
# Epoch 26 training-Loss: 0.3745 validation-Loss 0.3670✓
# Epoch 27 training-Loss: 0.3732 validation-Loss 0.3664✓
# Epoch 28 training-Loss: 0.3715 validation-Loss 0.3639✓
# Epoch 29 training-Loss: 0.3705 validation-Loss 0.3631✓
# Epoch 30 training-Loss: 0.3687 validation-Loss 0.3607✓
# Epoch 31 training-Loss: 0.3680 validation-Loss 0.3606
# Epoch 32 training-Loss: 0.3662 validation-Loss 0.3584✓
# Epoch 33 training-Loss: 0.3656 validation-Loss 0.3585
# Epoch 34 training-Loss: 0.3640 validation-Loss 0.3563✓
# Epoch 35 training-Loss: 0.3633 validation-Loss 0.3567
# Epoch 36 training-Loss: 0.3617 validation-Loss 0.3545✓
# Epoch 37 training-Loss: 0.3613 validation-Loss 0.3546
# Epoch 38 training-Loss: 0.3598 validation-Loss 0.3528✓
# Epoch 39 training-Loss: 0.3589 validation-Loss 0.3531
# Epoch 40 training-Loss: 0.3580 validation-Loss 0.3516✓
# Epoch 41 training-Loss: 0.3570 validation-Loss 0.3521
# Epoch 42 training-Loss: 0.3561 validation-Loss 0.3505✓
# Epoch 43 training-Loss: 0.3555 validation-Loss 0.3513
# Epoch 44 training-Loss: 0.3544 validation-Loss 0.3497✓
# Epoch 45 training-Loss: 0.3539 validation-Loss 0.3502
# Epoch 46 training-Loss: 0.3527 validation-Loss 0.3488✓
# Epoch 47 training-Loss: 0.3522 validation-Loss 0.3493
# Epoch 48 training-Loss: 0.3510 validation-Loss 0.3479✓
# Epoch 49 training-Loss: 0.3509 validation-Loss 0.3491
# Epoch 50 training-Loss: 0.3497 validation-Loss 0.3477
# Epoch 51 training-Loss: 0.3494 validation-Loss 0.3482
# Epoch 52 training-Loss: 0.3482 validation-Loss 0.3471✓
# Epoch 53 training-Loss: 0.3480 validation-Loss 0.3479
# Epoch 54 training-Loss: 0.3470 validation-Loss 0.3468
# Epoch 55 training-Loss: 0.3466 validation-Loss 0.3475
# Epoch 56 training-Loss: 0.3458 validation-Loss 0.3465✓
# Epoch 57 training-Loss: 0.3455 validation-Loss 0.3472
# Epoch 58 training-Loss: 0.3447 validation-Loss 0.3466
# Epoch 59 training-Loss: 0.3442 validation-Loss 0.3467
# Epoch 60 training-Loss: 0.3437 validation-Loss 0.3465
# Epoch 61 training-Loss: 0.3432 validation-Loss 0.3466
# Epoch 62 training-Loss: 0.3427 validation-Loss 0.3466
# Epoch 63 training-Loss: 0.3421 validation-Loss 0.3465
# Epoch 64 training-Loss: 0.3413 validation-Loss 0.3463
# Epoch 65 training-Loss: 0.3411 validation-Loss 0.3466
# Epoch 66 training-Loss: 0.3403 validation-Loss 0.3466
# Epoch 67 training-Loss: 0.3402 validation-Loss 0.3465
# Epoch 68 training-Loss: 0.3395 validation-Loss 0.3463
# Epoch 69 training-Loss: 0.3392 validation-Loss 0.3464
# Epoch 70 training-Loss: 0.3384 validation-Loss 0.3457✓
# Epoch 71 training-Loss: 0.3382 validation-Loss 0.3466
# Epoch 72 training-Loss: 0.3376 validation-Loss 0.3460
# Epoch 73 training-Loss: 0.3371 validation-Loss 0.3467
# Epoch 74 training-Loss: 0.3369 validation-Loss 0.3459
# Epoch 75 training-Loss: 0.3362 validation-Loss 0.3467
# Epoch 76 training-Loss: 0.3360 validation-Loss 0.3460
# Epoch 77 training-Loss: 0.3153 validation-Loss 0.3677
# Epoch 78 training-Loss: 0.3081 validation-Loss 0.3676
# Epoch 79 training-Loss: 0.3085 validation-Loss 0.3669
# Epoch 80 training-Loss: 0.3086 validation-Loss 0.3664
# Epoch 81 training-Loss: 0.3087 validation-Loss 0.3659
# Epoch 82 training-Loss: 0.3088 validation-Loss 0.3658
# Epoch 83 training-Loss: 0.3003 validation-Loss 0.3776
# Epoch 84 training-Loss: 0.2977 validation-Loss 0.3798
# Epoch 85 training-Loss: 0.2976 validation-Loss 0.3803
# patience clompleted. Aborting training

# %%
import torch
from torch import optim
from tqdm import tqdm

trainingloader  = gl2.dataloader_collection.train
valloader       = gl2.dataloader_collection.val
testloader      = gl2.dataloader_collection.test

from src.utils.textformatting import checkmark
# data


device = 'cuda' if torch.cuda.is_available() else 'cpu'

model2 = GRU_GATv2_Regressor(input_dim=f, hidden_dim=hidden_dim_gru, gat_hidden_dim=hidden_dim_gat, output_dim=1, num_layers=2).to(device)
optimizer = optim.Adam(model2.parameters(), lr=1e-4)
criterion = nn.MSELoss()

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=15,
    min_lr=1e-7
)

patience_counter = 0
best_val_loss = 1e6

for epoch in range(epochs):

    # TRAINING PHASE
    model2.train()
    training_loss = 0.0
    for deepdata in trainingloader:
        X_t = deepdata.x.to(device)  # [nodes, features, seq_len]
        y_t = deepdata.y.to(device)  # [nodes, 1]
        e_i = deepdata.edge_index.to(device)

        X_t = X_t.permute(0, 2, 1)  # [nodes, seq_len, features]

        optimizer.zero_grad()
        y_pred = model2(X_t, e_i)          # [nodes, output_dim]
        loss = criterion(y_pred, y_t)
        loss.backward()
        optimizer.step()

        training_loss += loss.item()# * X_t.size(0)

    # VALIDATION PHASE
    model2.eval()
    validation_loss = 0
    with torch.no_grad():
        for deepdata in valloader:
            X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
            y_t = deepdata.y.to(device)
            e_i = deepdata.edge_index.to(device)            

            X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
            y_pred = model2(X_t, e_i)                  # [nodes, output_dim]
            loss = criterion(y_pred, y_t)
            validation_loss += loss.item()

    training_loss  = training_loss / len(trainingloader)
    validation_loss= validation_loss / len(valloader)

    val_improved = validation_loss <( best_val_loss - delta)
    update = f"Epoch {epoch+1} training-Loss: {training_loss:.4f} validation-Loss {validation_loss:.4f}"
    # if so => save best model
    if val_improved:
        best_val_loss   = validation_loss
        patience_counter= 0
        best_model_state= model2.state_dict().copy()  
        update += checkmark
    else:
        patience_counter += 1       

    if patience_counter > patience:
        break

       
    scheduler.step(validation_loss)
    print(update)

model2.load_state_dict(best_model_state)

import torch
import matplotlib.pyplot as plt
import seaborn as sns

node_idx = 15  # the node you’re tracking

model2.eval()
node_preds = []

with torch.no_grad():
    for deepdata in testloader:
        X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
        e_i = deepdata.edge_index.to(device)        
        X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
        y_pred = model2(X_t,e_i)                  # [nodes, output_dim]
        node_preds.append(y_pred[node_idx].cpu().item())

# Ground truth for this node
node_gt = [deepdata.y[node_idx].item() for deepdata in testloader]

# Plot
sns.lineplot(node_gt, label='GT')
sns.lineplot(node_preds, label='Pred')
plt.xlabel('Timepoint / validation window index')
plt.ylabel('Value')
plt.title(f'Node {node_idx} predictions vs ground truth')
plt.legend()
# plt.xlim(700,800)
plt.show()
# Out:
# Epoch 1 training-Loss: 0.7770 validation-Loss 1.0855✓
# Epoch 2 training-Loss: 0.6207 validation-Loss 0.8436✓
# Epoch 3 training-Loss: 0.5537 validation-Loss 0.7027✓
# Epoch 4 training-Loss: 0.5136 validation-Loss 0.6087✓
# Epoch 5 training-Loss: 0.4838 validation-Loss 0.5450✓
# Epoch 6 training-Loss: 0.4593 validation-Loss 0.5015✓
# Epoch 7 training-Loss: 0.4426 validation-Loss 0.4753✓
# Epoch 8 training-Loss: 0.4296 validation-Loss 0.4493✓
# Epoch 9 training-Loss: 0.4184 validation-Loss 0.4368✓
# Epoch 10 training-Loss: 0.4102 validation-Loss 0.4170✓
# Epoch 11 training-Loss: 0.4021 validation-Loss 0.4113✓
# Epoch 12 training-Loss: 0.3958 validation-Loss 0.3940✓
# Epoch 13 training-Loss: 0.3899 validation-Loss 0.3906✓
# Epoch 14 training-Loss: 0.3848 validation-Loss 0.3778✓
# Epoch 15 training-Loss: 0.3805 validation-Loss 0.3747✓
# Epoch 16 training-Loss: 0.3756 validation-Loss 0.3671✓
# Epoch 17 training-Loss: 0.3728 validation-Loss 0.3628✓
# Epoch 18 training-Loss: 0.3681 validation-Loss 0.3576✓
# Epoch 19 training-Loss: 0.3657 validation-Loss 0.3525✓
# Epoch 20 training-Loss: 0.3610 validation-Loss 0.3496✓
# Epoch 21 training-Loss: 0.3593 validation-Loss 0.3453✓
# Epoch 22 training-Loss: 0.3553 validation-Loss 0.3432✓
# Epoch 23 training-Loss: 0.3541 validation-Loss 0.3385✓
# Epoch 24 training-Loss: 0.3498 validation-Loss 0.3397
# Epoch 25 training-Loss: 0.3493 validation-Loss 0.3339✓
# Epoch 26 training-Loss: 0.3449 validation-Loss 0.3358
# Epoch 27 training-Loss: 0.3448 validation-Loss 0.3296✓
# Epoch 28 training-Loss: 0.3410 validation-Loss 0.3332
# Epoch 29 training-Loss: 0.3407 validation-Loss 0.3280✓
# Epoch 30 training-Loss: 0.3380 validation-Loss 0.3290
# Epoch 31 training-Loss: 0.3367 validation-Loss 0.3271✓
# Epoch 32 training-Loss: 0.3353 validation-Loss 0.3273
# Epoch 33 training-Loss: 0.3332 validation-Loss 0.3251✓
# Epoch 34 training-Loss: 0.3326 validation-Loss 0.3255
# Epoch 35 training-Loss: 0.3304 validation-Loss 0.3238✓
# Epoch 36 training-Loss: 0.3299 validation-Loss 0.3246
# Epoch 37 training-Loss: 0.3280 validation-Loss 0.3230✓
# Epoch 38 training-Loss: 0.3274 validation-Loss 0.3243
# Epoch 39 training-Loss: 0.3256 validation-Loss 0.3211✓
# Epoch 40 training-Loss: 0.3251 validation-Loss 0.3230
# Epoch 41 training-Loss: 0.3234 validation-Loss 0.3204✓
# Epoch 42 training-Loss: 0.3230 validation-Loss 0.3226
# Epoch 43 training-Loss: 0.3217 validation-Loss 0.3196✓
# Epoch 44 training-Loss: 0.3213 validation-Loss 0.3217
# Epoch 45 training-Loss: 0.3198 validation-Loss 0.3193
# Epoch 46 training-Loss: 0.3194 validation-Loss 0.3211
# Epoch 47 training-Loss: 0.3182 validation-Loss 0.3185✓
# Epoch 48 training-Loss: 0.3177 validation-Loss 0.3204
# Epoch 49 training-Loss: 0.3168 validation-Loss 0.3187
# Epoch 50 training-Loss: 0.3164 validation-Loss 0.3198
# Epoch 51 training-Loss: 0.3154 validation-Loss 0.3188
# Epoch 52 training-Loss: 0.3150 validation-Loss 0.3197
# Epoch 53 training-Loss: 0.3142 validation-Loss 0.3188
# Epoch 54 training-Loss: 0.3138 validation-Loss 0.3195
# Epoch 55 training-Loss: 0.3131 validation-Loss 0.3190
# Epoch 56 training-Loss: 0.3127 validation-Loss 0.3194
# Epoch 57 training-Loss: 0.3118 validation-Loss 0.3193
# Epoch 58 training-Loss: 0.3115 validation-Loss 0.3194
# Epoch 59 training-Loss: 0.3106 validation-Loss 0.3195
# Epoch 60 training-Loss: 0.3104 validation-Loss 0.3193
# Epoch 61 training-Loss: 0.3097 validation-Loss 0.3200
# Epoch 62 training-Loss: 0.3095 validation-Loss 0.3192
# Epoch 63 training-Loss: 0.3087 validation-Loss 0.3203
# Epoch 64 training-Loss: 0.2869 validation-Loss 0.3372
# Epoch 65 training-Loss: 0.2829 validation-Loss 0.3355
# Epoch 66 training-Loss: 0.2831 validation-Loss 0.3354
# Epoch 67 training-Loss: 0.2831 validation-Loss 0.3347
# Epoch 68 training-Loss: 0.2832 validation-Loss 0.3344
# Epoch 69 training-Loss: 0.2831 validation-Loss 0.3341
# Epoch 70 training-Loss: 0.2829 validation-Loss 0.3340
# Epoch 71 training-Loss: 0.2828 validation-Loss 0.3338
# Epoch 72 training-Loss: 0.2826 validation-Loss 0.3337
# Epoch 73 training-Loss: 0.2824 validation-Loss 0.3336
# Epoch 74 training-Loss: 0.2822 validation-Loss 0.3335
# Epoch 75 training-Loss: 0.2820 validation-Loss 0.3334
# Epoch 76 training-Loss: 0.2818 validation-Loss 0.3333
# Epoch 77 training-Loss: 0.2816 validation-Loss 0.3332
# Epoch 78 training-Loss: 0.2815 validation-Loss 0.3332
# Epoch 79 training-Loss: 0.2813 validation-Loss 0.3331
# Epoch 80 training-Loss: 0.2705 validation-Loss 0.3428
# Epoch 81 training-Loss: 0.2694 validation-Loss 0.3438
# Epoch 82 training-Loss: 0.2693 validation-Loss 0.3436
# Epoch 83 training-Loss: 0.2693 validation-Loss 0.3434
# Epoch 84 training-Loss: 0.2693 validation-Loss 0.3432
# Epoch 85 training-Loss: 0.2692 validation-Loss 0.3431
# Epoch 86 training-Loss: 0.2691 validation-Loss 0.3429
# Epoch 87 training-Loss: 0.2690 validation-Loss 0.3428
# Epoch 88 training-Loss: 0.2690 validation-Loss 0.3427
# Epoch 89 training-Loss: 0.2689 validation-Loss 0.3426
# Epoch 90 training-Loss: 0.2688 validation-Loss 0.3425
# Epoch 91 training-Loss: 0.2687 validation-Loss 0.3424
# Epoch 92 training-Loss: 0.2686 validation-Loss 0.3424
# Epoch 93 training-Loss: 0.2685 validation-Loss 0.3423
# Epoch 94 training-Loss: 0.2684 validation-Loss 0.3422
# Epoch 95 training-Loss: 0.2683 validation-Loss 0.3422
# Epoch 96 training-Loss: 0.2631 validation-Loss 0.3451
# Epoch 97 training-Loss: 0.2627 validation-Loss 0.3460

# %%
import torch
from torch import optim
from tqdm import tqdm

trainingloader  = gl3.dataloader_collection.train
valloader       = gl3.dataloader_collection.val
testloader      = gl3.dataloader_collection.test

from src.utils.textformatting import checkmark
# data


device = 'cuda' if torch.cuda.is_available() else 'cpu'

model3 = GRU_GATv2_Regressor(input_dim=f, hidden_dim=hidden_dim_gru, gat_hidden_dim=hidden_dim_gat, output_dim=1, num_layers=2).to(device)
optimizer = optim.Adam(model3.parameters(), lr=0.5e-4)
criterion = nn.MSELoss()

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=5,
    min_lr=1e-7
)

patience_counter = 0
best_val_loss = 1e6

for epoch in range(epochs):

    # TRAINING PHASE
    model3.train()
    training_loss = 0.0
    for deepdata in trainingloader:
        X_t = deepdata.x.to(device)  # [nodes, features, seq_len]
        y_t = deepdata.y.to(device)  # [nodes, 1]
        e_i = deepdata.edge_index.to(device)

        X_t = X_t.permute(0, 2, 1)  # [nodes, seq_len, features]

        optimizer.zero_grad()
        y_pred = model3(X_t, e_i)          # [nodes, output_dim]
        loss = criterion(y_pred, y_t)
        loss.backward()
        optimizer.step()

        training_loss += loss.item()# * X_t.size(0)

    # VALIDATION PHASE
    model3.eval()
    validation_loss = 0
    with torch.no_grad():
        for deepdata in valloader:
            X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
            y_t = deepdata.y.to(device)
            e_i = deepdata.edge_index.to(device)            

            X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
            y_pred = model3(X_t, e_i)                  # [nodes, output_dim]
            loss = criterion(y_pred, y_t)
            validation_loss += loss.item()

    training_loss  = training_loss / len(trainingloader)
    validation_loss= validation_loss / len(valloader)

    val_improved = validation_loss <( best_val_loss - delta)
    update = f"Epoch {epoch+1} training-Loss: {training_loss:.4f} validation-Loss {validation_loss:.4f}"
    # if so => save best model
    if val_improved:
        best_val_loss   = validation_loss
        patience_counter= 0
        best_model_state= model3.state_dict().copy()  
        update += checkmark
    else:
        patience_counter += 1       

    if patience_counter > patience:
        break

       
    scheduler.step(validation_loss)
    print(update)

model3.load_state_dict(best_model_state)

import torch
import matplotlib.pyplot as plt
import seaborn as sns

node_idx = 223  # the node you’re tracking

model3.eval()
node_preds = []

with torch.no_grad():
    for deepdata in testloader:
        X_t = deepdata.x.to(device)          # [nodes, features, seq_len]
        e_i = deepdata.edge_index.to(device)        
        X_t = X_t.permute(0, 2, 1)          # [nodes, seq_len, features]
        y_pred = model3(X_t,e_i)                  # [nodes, output_dim]
        node_preds.append(y_pred[node_idx].cpu().item())

# Ground truth for this node
node_gt = [deepdata.y[node_idx].item() for deepdata in testloader]

# Plot
sns.lineplot(node_gt, label='GT')
sns.lineplot(node_preds, label='Pred')
plt.xlabel('Timepoint / validation window index')
plt.ylabel('Value')
plt.title(f'Node {node_idx} predictions vs ground truth')
plt.legend()
# plt.xlim(700,800)
plt.show()
# Out:
# Epoch 1 training-Loss: 0.8292 validation-Loss 1.4046✓
# Epoch 2 training-Loss: 0.6703 validation-Loss 1.1792✓
# Epoch 3 training-Loss: 0.6031 validation-Loss 1.0190✓
# Epoch 4 training-Loss: 0.5488 validation-Loss 0.8819✓
# Epoch 5 training-Loss: 0.5047 validation-Loss 0.7646✓
# Epoch 6 training-Loss: 0.4700 validation-Loss 0.6697✓
# Epoch 7 training-Loss: 0.4465 validation-Loss 0.6009✓
# Epoch 8 training-Loss: 0.4280 validation-Loss 0.5491✓
# Epoch 9 training-Loss: 0.4138 validation-Loss 0.5097✓
# Epoch 10 training-Loss: 0.4025 validation-Loss 0.4793✓
# Epoch 11 training-Loss: 0.3934 validation-Loss 0.4550✓
# Epoch 12 training-Loss: 0.3857 validation-Loss 0.4357✓
# Epoch 13 training-Loss: 0.3789 validation-Loss 0.4200✓
# Epoch 14 training-Loss: 0.3732 validation-Loss 0.4073✓
# Epoch 15 training-Loss: 0.3682 validation-Loss 0.3965✓
# Epoch 16 training-Loss: 0.3637 validation-Loss 0.3877✓
# Epoch 17 training-Loss: 0.3597 validation-Loss 0.3801✓
# Epoch 18 training-Loss: 0.3561 validation-Loss 0.3737✓
# Epoch 19 training-Loss: 0.3527 validation-Loss 0.3683✓
# Epoch 20 training-Loss: 0.3497 validation-Loss 0.3636✓
# Epoch 21 training-Loss: 0.3470 validation-Loss 0.3595✓
# Epoch 22 training-Loss: 0.3444 validation-Loss 0.3559✓
# Epoch 23 training-Loss: 0.3421 validation-Loss 0.3528✓
# Epoch 24 training-Loss: 0.3399 validation-Loss 0.3502✓
# Epoch 25 training-Loss: 0.3379 validation-Loss 0.3478✓
# Epoch 26 training-Loss: 0.3360 validation-Loss 0.3457✓
# Epoch 27 training-Loss: 0.3341 validation-Loss 0.3440✓
# Epoch 28 training-Loss: 0.3325 validation-Loss 0.3424✓
# Epoch 29 training-Loss: 0.3309 validation-Loss 0.3411✓
# Epoch 30 training-Loss: 0.3294 validation-Loss 0.3399✓
# Epoch 31 training-Loss: 0.3280 validation-Loss 0.3387✓
# Epoch 32 training-Loss: 0.3266 validation-Loss 0.3379✓
# Epoch 33 training-Loss: 0.3253 validation-Loss 0.3368✓
# Epoch 34 training-Loss: 0.3240 validation-Loss 0.3361✓
# Epoch 35 training-Loss: 0.3228 validation-Loss 0.3354✓
# Epoch 36 training-Loss: 0.3217 validation-Loss 0.3348✓
# Epoch 37 training-Loss: 0.3206 validation-Loss 0.3342✓
# Epoch 38 training-Loss: 0.3196 validation-Loss 0.3337✓
# Epoch 39 training-Loss: 0.3186 validation-Loss 0.3333
# Epoch 40 training-Loss: 0.3177 validation-Loss 0.3329✓
# Epoch 41 training-Loss: 0.3167 validation-Loss 0.3325
# Epoch 42 training-Loss: 0.3159 validation-Loss 0.3322✓
# Epoch 43 training-Loss: 0.3150 validation-Loss 0.3318
# Epoch 44 training-Loss: 0.3142 validation-Loss 0.3316✓
# Epoch 45 training-Loss: 0.3135 validation-Loss 0.3312
# Epoch 46 training-Loss: 0.3127 validation-Loss 0.3310✓
# Epoch 47 training-Loss: 0.3119 validation-Loss 0.3308
# Epoch 48 training-Loss: 0.3112 validation-Loss 0.3305
# Epoch 49 training-Loss: 0.3105 validation-Loss 0.3303✓
# Epoch 50 training-Loss: 0.3099 validation-Loss 0.3301
# Epoch 51 training-Loss: 0.3092 validation-Loss 0.3299
# Epoch 52 training-Loss: 0.3086 validation-Loss 0.3297✓
# Epoch 53 training-Loss: 0.3080 validation-Loss 0.3296
# Epoch 54 training-Loss: 0.3074 validation-Loss 0.3294
# Epoch 55 training-Loss: 0.3068 validation-Loss 0.3292✓
# Epoch 56 training-Loss: 0.3062 validation-Loss 0.3291
# Epoch 57 training-Loss: 0.3057 validation-Loss 0.3289
# Epoch 58 training-Loss: 0.3052 validation-Loss 0.3289
# Epoch 59 training-Loss: 0.3047 validation-Loss 0.3286✓
# Epoch 60 training-Loss: 0.3042 validation-Loss 0.3286
# Epoch 61 training-Loss: 0.3037 validation-Loss 0.3284
# Epoch 62 training-Loss: 0.3032 validation-Loss 0.3283
# Epoch 63 training-Loss: 0.3027 validation-Loss 0.3282
# Epoch 64 training-Loss: 0.3022 validation-Loss 0.3282
# Epoch 65 training-Loss: 0.3018 validation-Loss 0.3280✓
# Epoch 66 training-Loss: 0.3013 validation-Loss 0.3281
# Epoch 67 training-Loss: 0.3009 validation-Loss 0.3279
# Epoch 68 training-Loss: 0.3005 validation-Loss 0.3280
# Epoch 69 training-Loss: 0.3001 validation-Loss 0.3278
# Epoch 70 training-Loss: 0.2997 validation-Loss 0.3279
# Epoch 71 training-Loss: 0.2993 validation-Loss 0.3276
# Epoch 72 training-Loss: 0.2989 validation-Loss 0.3279
# Epoch 73 training-Loss: 0.2985 validation-Loss 0.3277
# Epoch 74 training-Loss: 0.2981 validation-Loss 0.3278
# Epoch 75 training-Loss: 0.2978 validation-Loss 0.3277
# Epoch 76 training-Loss: 0.2974 validation-Loss 0.3278
# Epoch 77 training-Loss: 0.2971 validation-Loss 0.3277
# Epoch 78 training-Loss: 0.2816 validation-Loss 0.3411
# Epoch 79 training-Loss: 0.2784 validation-Loss 0.3408
# Epoch 80 training-Loss: 0.2785 validation-Loss 0.3402
# Epoch 81 training-Loss: 0.2785 validation-Loss 0.3398
# Epoch 82 training-Loss: 0.2785 validation-Loss 0.3397
# Epoch 83 training-Loss: 0.2785 validation-Loss 0.3396
# Epoch 84 training-Loss: 0.2711 validation-Loss 0.3447
# Epoch 85 training-Loss: 0.2704 validation-Loss 0.3457
# Epoch 86 training-Loss: 0.2703 validation-Loss 0.3459
# Epoch 87 training-Loss: 0.2703 validation-Loss 0.3458
# Epoch 88 training-Loss: 0.2702 validation-Loss 0.3458
# Epoch 89 training-Loss: 0.2701 validation-Loss 0.3457
# Epoch 90 training-Loss: 0.2665 validation-Loss 0.3471
# Epoch 91 training-Loss: 0.2664 validation-Loss 0.3476
# Epoch 92 training-Loss: 0.2663 validation-Loss 0.3479
# Epoch 93 training-Loss: 0.2662 validation-Loss 0.3480
# Epoch 94 training-Loss: 0.2662 validation-Loss 0.3480
# Epoch 95 training-Loss: 0.2661 validation-Loss 0.3481
# Epoch 96 training-Loss: 0.2644 validation-Loss 0.3485
# Epoch 97 training-Loss: 0.2643 validation-Loss 0.3487
# Epoch 98 training-Loss: 0.2643 validation-Loss 0.3488
# Epoch 99 training-Loss: 0.2643 validation-Loss 0.3489
# Epoch 100 training-Loss: 0.2642 validation-Loss 0.3489
# Epoch 101 training-Loss: 0.2642 validation-Loss 0.3489
# Epoch 102 training-Loss: 0.2633 validation-Loss 0.3491
# Epoch 103 training-Loss: 0.2633 validation-Loss 0.3492
# Epoch 104 training-Loss: 0.2633 validation-Loss 0.3492
# Epoch 105 training-Loss: 0.2633 validation-Loss 0.3493
# Epoch 106 training-Loss: 0.2633 validation-Loss 0.3493
# Epoch 107 training-Loss: 0.2632 validation-Loss 0.3493
# Epoch 108 training-Loss: 0.2628 validation-Loss 0.3494
# Epoch 109 training-Loss: 0.2628 validation-Loss 0.3494
# Epoch 110 training-Loss: 0.2628 validation-Loss 0.3495
# Epoch 111 training-Loss: 0.2628 validation-Loss 0.3495
# Epoch 112 training-Loss: 0.2628 validation-Loss 0.3495
# Epoch 113 training-Loss: 0.2628 validation-Loss 0.3495
# Epoch 114 training-Loss: 0.2625 validation-Loss 0.3495
# Epoch 115 training-Loss: 0.2625 validation-Loss 0.3496

# %%
import pandas as pd
import torch

t1 = '2022-09-14'
t2 = '2022-12-25'

def return_model_preds(model):

    model.eval()

    all_data = []

    t1_dt = pd.to_datetime(t1)
    t2_dt = pd.to_datetime(t2)

    # Generate daily dates
    dates = pd.date_range(start=t1_dt, end=t2_dt - pd.Timedelta(days=1), freq='D')
    date_idx = 0  # to iterate over dates

    with torch.no_grad():
        for deepdata in testloader:
            X_t = deepdata.x.to(device)           # [nodes, features, seq_len]
            e_i = deepdata.edge_index.to(device)
            X_t = X_t.permute(0, 2, 1)           # [nodes, seq_len, features]
            y_pred = model(X_t, e_i)            # [nodes, output_dim]

            current_date = dates[date_idx]       # pick the date for this batch
            
            # For each node, append pred and target
            for node_idx in range(y_pred.shape[0]):
                all_data.append({
                    'node': node_idx,
                    'pred': y_pred[node_idx].cpu().item(),
                    'target': deepdata.y[node_idx].item(),
                    'timestamp': current_date
                })

            date_idx +=1
            if date_idx >= len(dates):
                break

    # Create a long DataFrame
    return pd.DataFrame(all_data)

# %%
# FAKE MODEL CLASS 

from src.models.base.predictions_manager import PredictionManager

class FakeClass:

    def __init__(self, model_name, dataorchestrator: DataOrchestrator):
        self.name = model_name
        self.prediction_mode = 'regression'
        self.clean_model_name = model_name
        self.model_class = 'gatv2_newgen'
        self.model_color = '#1b9e77'

        self.predictions = PredictionManager(dataorchestrator.config, dataorchestrator.column_registration)

model1_fc             = FakeClass('gru_gatv2_regressor_ig', data_orchestrator)
model1_fc.predictions.add_horizon_predictions('test', return_model_preds(model1), 0)

model2_fc             = FakeClass('gru_gatv2_regressor_gn', data_orchestrator)
model2_fc.predictions.add_horizon_predictions('test', return_model_preds(model2), 0)

model3_fc             = FakeClass('gru_gatv2_regressor_commutergraph', data_orchestrator)
model3_fc.predictions.add_horizon_predictions('test', return_model_preds(model3), 0)

# %%
from src.dataloading import ShallowDataLoaderManager, GraphDataLoaderManager, BaseLineDataLoaderManager
from src.models import PersistenceModel, ClimateologyModel

ps = PersistenceModel(sl)
cm = ClimateologyModel(sl)

ps.forecast('test')
raw_f1 = ps.show_forecasts([26], 'test')

cm.forecast('test')
raw_f2 = cm.show_forecasts([26], 'test')

# %%
from src.models import NodeLSTMModel

n_epochs        = 100
lr              = 0.0001
min_delta       = 0.0001
loss            = 'mse'

global_hparams = {
    "lr"                : lr,
    "n_epochs"          : n_epochs,
    "scheduler"         : 'plateau',
    "scheduler_kwargs"  :  {'mode': 'min', 'factor': 0.5, 'patience': 6},
    'min_delta'         : min_delta,
    'loss'              : loss,
    'patience'          : 20,
    }



lstm = NodeLSTMModel(dl, name = 'lstmmodel')
lstm.set_model_hparams()
lstm.set_global_hparams(**global_hparams)
lstm.train()
lstm.forecast()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 23
#      21 lstm.set_model_hparams()
#      22 lstm.set_global_hparams(**global_hparams)
# ---> 23 lstm.train()
#      24 lstm.forecast()
#
# File /scratch/de-schrijvers/projects/infectious_disease_gnn/src/models/deep/deepmodel.py:340, in DeepModel.train(self)
#     335     snapshot = snapshot.to(self.device)
#     337     # different models have different input and output in steps
#     338     # taken care of using the strategy
# --> 340     loss_train = self.strategy.training_step(
#     341         model       = self.model,
#     342         snapshot    = snapshot,
#     343         optimizer   = self.optimizer,
#     344         loss_fn     = self.loss
#     345     )
#     347     total_loss += loss_train
#     349 train_loss = total_loss / L_train
#
# File /scratch/de-schrijvers/projects/infectious_disease_gnn/src/models/deep/vanilla/strategies/recurrentlstm_strategy.py:28, in RecurrentLSTMStrategy.training_step(self, model, snapshot, optimizer, loss_fn)
#      25 self.cell_state = self._detach_and_move(c, snapshot.x.device)
#      27 loss = loss_fn(y_hat, snapshot.y)
# ---> 28 loss.backward()
#      29 optimizer.step()
#      30 return loss.item()
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)    519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/.conda/envs/gnenv/lib/python3.11/site-packages/torch/autograd/graph.py:768, in _engine_run_backward(t_outputs, *args, **kwargs)
#     766     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767 try:
# --> 768     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769         t_outputs, *args, **kwargs
#     770     )  # Calls into the C++ engine to run the backward pass
#     771 finally:
#     772     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
from src.evaluation import Evaluator

e = Evaluator([ps, model1_fc, model2_fc, model3_fc]).add_evaluation()
raw_figure = e.plotter.plot_metric_compilation(plot_types = ['box','box','box','box'], metrics = ['rmse','pearson_corr','spearman_corr','ccc'])

f_evaluation = (raw_figure
    .labels.change_suptitle(suptitle='Evaluation daily covid models', fontsize = 14, fontweight = 'bold')
    .labels.set_suptitle_y(y=1.05)
    .labels.change_title('root mean square error (rmse) distribution', fontweight = 'bold',         ax = 0)      
    .labels.change_title('Pearson correlation ($\\rho_{p}$) distribution', fontweight = 'bold',     ax = 1)
    .labels.change_title('Spearman correlation ($\\rho_s$) distribution',  fontweight = 'bold',     ax = 2)
    .labels.change_title('Cross-concordance correlation (ccc) distribution', fontweight = 'bold',   ax = 3)    
    .labels.change_ylab('')
    .labels.change_xlab("")
    .ticks.change_xticks([], ax = 0)
    .ticks.change_xticks([], ax = 1)    
    .ticks.change_yticks(ticks = [0,0.5,1], ax = 1)
    .ticks.change_yticks(ticks = [0,0.5,1], ax = 2)
    .ticks.change_yticks(ticks = [0,0.2,0.4,0.6,0.8,1], ax = 3)    
    .ticks.rotate_xticks(30)
    .layout.set_ylim([0,1],ax = 1)
    .layout.set_ylim([0,1],ax = 2)
    .layout.set_ylim([0,1],ax = 3)        
    .labels.change_legend_title('Model family',fontweight = 'bold',ax=0)
    .labels.set_tag('A', y = 1.1, ax = 0)   
    .labels.set_tag('B', y = 1.1, ax = 1) 
    .labels.set_tag('C', y = 1.1, ax = 2) 
    .labels.set_tag('D', y = 1.1, ax = 3)      
    .legend.move('upper left', ax = 0)      
    .change_figsize(20,8)         
    )
f_evaluation.show()
# Out:
# computing metrics:   0%|                                                                                                                                                                | 0/6 [00:00<?, ?it/s]
# computing metrics: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:03<00:00,  1.51it/s]
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
