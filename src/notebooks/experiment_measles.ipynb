# %%
from src.configmanager.experimentconfigmanager import ExperimentConfigManager

loss = 'mse'

hyperparameters = {
    "lr"                : lr,
    "n_epochs"          : n_epochs,
    "scheduler_kwargs"  : {'step_size':20, 'gamma':0.95},
    'min_delta'         : min_delta,
    'loss'              : loss
    }

experiment1 = ExperimentConfigManager()
experiment1.define(experiment_name = 'self_non0', 
                   disease_name    = 'influenza',
                   model           = 'tgcn', 

                   hyperparameters = hyperparameters, 

                   graphs=['boolean_neighbors_selfmn','identity_graph','gravity_model_dense_selfmn','gravity_model_sparse_selfmn'])
experiment1.execute('self_non0')
# Out:
# GNN temporal windowing: extending data collection from 2020-06-01 to 2020-08-24 (+12 weeks)
# GNN temporal windowing: extending data collection from 2020-06-01 to 2020-08-24 (+12 weeks)
# GNN temporal windowing: extending data collection from 2020-06-01 to 2020-08-24 (+12 weeks)
# GNN temporal windowing: extending data collection from 2020-06-01 to 2020-08-24 (+12 weeks)
# GNN temporal windowing: extending data collection from 2020-06-01 to 2020-08-24 (+12 weeks)
#
# 🧪 Snapshot 0 validation summary:
# ➡️  Predicted shape: torch.Size([38, 1])
# ➡️  Ground truth shape: torch.Size([38, 1])
# ✅ Snapshot ran successfully
# Dataloader Snapshot: GraphDataLoaderEntry(x=[38, 3, 12], y=[38, 1], edge_index=[2, 210], edge_weight=[210])
# Epoch 1 train loss: 0.5830, val loss: 0.6158 ✓ (new best)
# Epoch 2 train loss: 0.4432, val loss: 0.4666 ✓ (new best)
# Epoch 3 train loss: 0.3848, val loss: 0.3987 ✓ (new best)
# Epoch 4 train loss: 0.3484, val loss: 0.3754 ✓ (new best)
# ...

# %%
import importlib.util
import sys
from datetime import date
import pandas as pd
import numpy as np
from typing import Dict, Literal, Optional
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates
import os
from pathlib import Path
from src.dataloading.epidataloader import EpiDataLoader
from src.dataloading.gnndataloader import GNNDataLoader

from src.models.spatiotemporal_baseline import TGCNModel
from src.utils import *

n_epochs = 100
lr       = 0.0002
min_delta = 0.001


min_date='2006-05-15'
max_date= '2020-06-01'
split_trainval= '2018-06-01'
split_valtest='2019-06-01'

# %%
epidata_nuts2 = GNNDataLoader('measles', get_data_env(), nuts_level='nuts1', min_date=min_date,max_date=max_date, include_population=True, horizon_size = 1, horizon_leadtime = 2, sequence_length=12)
epidata_nuts2.add_time_features()
epidata_nuts2.log_transform_target()
epidata_nuts2.set_splits(split_trainval,split_valtest)
epidata_nuts2.normalize()
epidata_nuts2.add_lagged_features(lags = 1)
epidata_nuts2.finalize()

loader1 = epidata_nuts2.copy(deep=True).retrieve_graph(graphname = 'identity_graph').construct_dataloaders()
loader2 = epidata_nuts2.copy(deep=True).retrieve_graph(graphname = 'boolean_neighbors_self0').construct_dataloaders()
loader3 = epidata_nuts2.copy(deep=True).retrieve_graph(graphname = 'boolean_neighbors_selfmn').construct_dataloaders()
# Out:
# Dataloader temporal windowing: extending data collection from 2006-05-15 to 2006-02-06 (+14 weeks)
# Dataloader temporal windowing: extending data collection from 2006-02-06 to 2005-10-31 (+14 weeks)
# Dataloader temporal windowing: extending data collection from 2006-02-06 to 2005-10-31 (+14 weeks)
# Dataloader temporal windowing: extending data collection from 2006-02-06 to 2005-10-31 (+14 weeks)

# %%
loader1.preview_dataloader(dataset = 'val',node_idx=12)
# Out:
# EpiDataLoader(disease=measles, nuts_level=nuts2, min_date=2005-10-31, max_date=2020-06-01, horizon_size=1, horizon_leadtime=2, sequence_length=12)

# %%
n_epochs = 150
lr = 0.0001

ml1 = TGCNModel(name = f'measles id graph', dataloader=loader1)
ml1.set_model_hparams()
ml1.set_global_hparams(lr = lr, n_epochs=n_epochs, scheduler_kwargs={'step_size':20, 'gamma':0.95}, min_delta = 0.00001, loss = 'mse')
ml1.run_snapshot(debug=True)
ml1.train(verbose=2)
ml1.forecast()
ml1.show_forecasts(dataset='test', target_h = 0)
# Out:
# 🧪 Snapshot 0 validation summary:
# ➡️  Predicted shape: torch.Size([38, 1])
# ➡️  Ground truth shape: torch.Size([38, 1])
# ✅ Snapshot ran successfully
# Dataloader Snapshot: GraphDataLoaderEntry(x=(38, 4, 12), y=(38, 1), edge_index=(2, 38), edge_weight=(38,))
# Epoch 1 train loss: 0.6160, val loss: 0.1623 ✓ (new best)
# Epoch 2 train loss: 0.5541, val loss: 0.1662 (patience: 1/15)
# Epoch 3 train loss: 0.5291, val loss: 0.1622 ✓ (new best)
# Epoch 4 train loss: 0.5086, val loss: 0.1622 (patience: 1/15)
# Epoch 5 train loss: 0.4989, val loss: 0.1621 ✓ (new best)
# Epoch 6 train loss: 0.4878, val loss: 0.1627 (patience: 1/15)
# Epoch 7 train loss: 0.4800, val loss: 0.1599 ✓ (new best)
# Epoch 8 train loss: 0.4696, val loss: 0.1599 (patience: 1/15)
# Epoch 9 train loss: 0.4597, val loss: 0.1634 (patience: 2/15)
# Epoch 10 train loss: 0.4524, val loss: 0.1624 (patience: 3/15)
# Epoch 11 train loss: 0.4445, val loss: 0.1648 (patience: 4/15)
# ...

# %%
ml2 = TGCNModel(name = f'measles bn 1', dataloader=loader2)
ml2.set_model_hparams()
ml2.set_global_hparams(lr = lr, n_epochs=n_epochs, scheduler_kwargs={'step_size':20, 'gamma':0.95}, min_delta = 0.00001, loss = 'mse')
ml2.run_snapshot(debug=True)
ml2.train(verbose=2)
ml2.forecast()
ml2.show_forecasts(dataset='test', target_h = 0)

ml3 = TGCNModel(name = f'measles bn 2', dataloader=loader3)
ml3.set_model_hparams()
ml3.set_global_hparams(lr = lr, n_epochs=n_epochs, scheduler_kwargs={'step_size':20, 'gamma':0.95}, min_delta = 0.00001, loss = 'mse')
ml3.run_snapshot(debug=True)
ml3.train(verbose=2)
ml3.forecast()
ml3.show_forecasts(dataset='test', target_h = 0)
