# %%
# !hpc-ticket
# !hpc-mount wissdaten

# %%
from src.utils import get_data_env
from src.dataloading import EpiConfig, DataOrchestrator, BaseLineDataLoaderManager, DeepDataLoaderManager, GraphDataLoaderManager
# get data
# get data
disease_name    = 'covid_daily'
nuts_level      = 'nuts3'
min_date        = '2020-03-02'
max_date        = '2023-01-01'
split_trainval  = '2022-06-01'
split_valtest   = '2022-09-01'
split_berlin    = False

horizon_size    = 1
horizon_leadtime= 7
sequence_length = 7
lag_num         = 1

config = EpiConfig(
    disease             = disease_name,
    data_env_dir        = get_data_env(),
    date_range          = (min_date, max_date),
    temporal_frequency   = "d",
    horizon_size        = horizon_size,
    sequence_length     = sequence_length,
    horizon_leadtime    = horizon_leadtime,
    lag_num             = lag_num,
    nuts_level          = nuts_level,
    log_transform       = ['incidence'],
    split_berlin        = split_berlin,
    include_population  = False,
    split_trainval      = split_trainval, 
    split_valtest       = split_valtest,
    target_column       = 'incidence',
    lag_column          = 'incidence',  
    verbose             = 0  ,
    weekly_time_index   = False,
    daily_time_index    = True,
    )    

data_orchestrator = (DataOrchestrator(config)
                        .load_raw()
                        .harmonize_raw()
                        .process_data()
                        .build_features()
                        .normalize()
                        .finalize()
                        )

sl = BaseLineDataLoaderManager(data_orchestrator)
dl = DeepDataLoaderManager(data_orchestrator).construct_dataloaders()

gl1 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('identity_graph').construct_dataloaders()
gl2 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('geographical_neighbors1').construct_dataloaders()
gl3 = GraphDataLoaderManager(data_orchestrator).retrieve_static_graph('static_commuter24_1').construct_dataloaders()

# %%
from src.models import GATv2LSTMModel

n_epochs        = 250
lr              = 0.0001
min_delta       = 0.0001
loss            = 'mse'

global_hparams = {
    "lr"                : lr,
    "n_epochs"          : n_epochs,
    "scheduler"         : 'plateau',
    "scheduler_kwargs"  :  {'mode': 'min', 'factor': 0.5, 'patience': 6},
    'min_delta'         : min_delta,
    'loss'              : loss,
    'patience'          : 20,
    }

# %%
gatv2_1 = GATv2LSTMModel(gl1, name = 'gatv2_identity_graph', verbose = 10)
gatv2_1.set_model_hparams()
gatv2_1.set_global_hparams(**global_hparams)
gatv2_1.train()
gatv2_1.forecast('test')
# Out:
# ==================================================
# ==             gatv2_identity_graph             ==
# ==================================================
# model_hparams_set ✓
# global_hparams_set ✓
# Dataloader Snapshot: GraphData(x=(400, 3, 7), y=(400, 1), edge_index=(2, 400), edge_weight=(400,))
# Epoch 001 train loss: 0.3531, val loss: 0.5114 ✓ (new best)
# Epoch 002 train loss: 0.2583, val loss: 0.4654 ✓ (new best)
# Epoch 003 train loss: 0.2423, val loss: 0.4307 ✓ (new best)
# Epoch 004 train loss: 0.2350, val loss: 0.4009 ✓ (new best)
# Epoch 005 train loss: 0.2289, val loss: 0.3851 ✓ (new best)
# Epoch 006 train loss: 0.2276, val loss: 0.3783 ✓ (new best)
# Epoch 007 train loss: 0.2238, val loss: 0.3706 ✓ (new best)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 gatv2_1.set_model_hparams()
#       3 gatv2_1.set_global_hparams(**global_hparams)
# ----> 4 gatv2_1.train()
#       5 gatv2_1.forecast('test')
#
# File /scratch/de-schrijvers/projects/infectious_disease_gnn/src/models/deep/deepmodel.py:341, in DeepModel.train(self)
#     338 total_loss = 0
#     340 for snapshot in train_loader:
# --> 341     snapshot = snapshot.to(self.device)
#     343     # different models have different input and output in steps
#     344     # taken care of using the strategy
#     346     loss_train = self.strategy.training_step(
#     347         model       = self.model,
#     348         snapshot    = snapshot,
#     349         optimizer   = self.optimizer,
#     350         loss_fn     = self.loss
#     351     )
#
# File /scratch/de-schrijvers/projects/infectious_disease_gnn/src/dataloading/dataloaders/graphloader/graphdataloadermanager.py:49, in GraphData.to(self, device)
#      46 def to(self, device: torch.device) -> 'GraphData':
#      47     """Move all tensors to the specified device (GPU)"""
#      48     return GraphData(
# ---> 49         x=self.x.to(device),
#      50         y=self.y.to(device),
#      51         edge_index=self.edge_index.to(device),
#      52         edge_weight=self.edge_weight.to(device)
#      53     )
#
# KeyboardInterrupt:

# %%
gatv2_2 = GATv2LSTMModel(gl2, name = 'gatv2_geographical_neighbors1', verbose = 10)
gatv2_2.set_model_hparams()
gatv2_2.set_global_hparams(**global_hparams)
gatv2_2.train()
gatv2_2.forecast('test')
# Out:
# ==================================================
# ==        gatv2_geographical_neighbors1         ==
# ==================================================
# model_hparams_set ✓
# global_hparams_set ✓
# Dataloader Snapshot: GraphData(x=(400, 3, 7), y=(400, 1), edge_index=(2, 2488), edge_weight=(2488,))
# Epoch 001 train loss: 0.2872, val loss: 0.5004 ✓ (new best)
# Epoch 002 train loss: 0.2168, val loss: 0.4545 ✓ (new best)
# Epoch 003 train loss: 0.2054, val loss: 0.4280 ✓ (new best)
# Epoch 004 train loss: 0.1974, val loss: 0.4122 ✓ (new best)
# Epoch 005 train loss: 0.1917, val loss: 0.4020 ✓ (new best)
# Epoch 006 train loss: 0.1895, val loss: 0.3949 ✓ (new best)
# Epoch 007 train loss: 0.1866, val loss: 0.3919 ✓ (new best)
# Epoch 008 train loss: 0.1852, val loss: 0.3867 ✓ (new best)
# Epoch 009 train loss: 0.1848, val loss: 0.3828 ✓ (new best)
# Epoch 010 train loss: 0.1840, val loss: 0.3794 ✓ (new best)
# Epoch 011 train loss: 0.1833, val loss: 0.3765 ✓ (new best)
# Epoch 012 train loss: 0.1833, val loss: 0.3729 ✓ (new best)
# Epoch 013 train loss: 0.1829, val loss: 0.3714 ✓ (new best)
# Epoch 014 train loss: 0.1828, val loss: 0.3681 ✓ (new best)
# Epoch 015 train loss: 0.1826, val loss: 0.3682 (patience: 1/20)
# Epoch 016 train loss: 0.1829, val loss: 0.3634 ✓ (new best)
# Epoch 017 train loss: 0.1823, val loss: 0.3614 ✓ (new best)
# Epoch 018 train loss: 0.1820, val loss: 0.3590 ✓ (new best)
# Epoch 019 train loss: 0.1826, val loss: 0.3571 ✓ (new best)
# Epoch 020 train loss: 0.1822, val loss: 0.3543 ✓ (new best)
# Epoch 021 train loss: 0.1821, val loss: 0.3524 ✓ (new best)
# Epoch 022 train loss: 0.1816, val loss: 0.3508 ✓ (new best)
# Epoch 023 train loss: 0.1817, val loss: 0.3477 ✓ (new best)
# Epoch 024 train loss: 0.1815, val loss: 0.3457 ✓ (new best)
# Epoch 025 train loss: 0.1810, val loss: 0.3435 ✓ (new best)
# Epoch 026 train loss: 0.1808, val loss: 0.3428 ✓ (new best)
# Epoch 027 train loss: 0.1807, val loss: 0.3405 ✓ (new best)
# Epoch 028 train loss: 0.1806, val loss: 0.3397 ✓ (new best)
# Epoch 029 train loss: 0.1802, val loss: 0.3374 ✓ (new best)
# Epoch 030 train loss: 0.1803, val loss: 0.3361 ✓ (new best)
# Epoch 031 train loss: 0.1795, val loss: 0.3331 ✓ (new best)
# Epoch 032 train loss: 0.1797, val loss: 0.3335 (patience: 1/20)
# Epoch 033 train loss: 0.1794, val loss: 0.3307 ✓ (new best)
# Epoch 034 train loss: 0.1790, val loss: 0.3304 ✓ (new best)
# Epoch 035 train loss: 0.1789, val loss: 0.3287 ✓ (new best)
# Epoch 036 train loss: 0.1786, val loss: 0.3268 ✓ (new best)
# Epoch 037 train loss: 0.1786, val loss: 0.3260 ✓ (new best)
# Epoch 038 train loss: 0.1781, val loss: 0.3242 ✓ (new best)
# Epoch 039 train loss: 0.1776, val loss: 0.3225 ✓ (new best)
# Epoch 040 train loss: 0.1778, val loss: 0.3221 ✓ (new best)
# Epoch 041 train loss: 0.1772, val loss: 0.3197 ✓ (new best)
# Epoch 042 train loss: 0.1769, val loss: 0.3174 ✓ (new best)
# Epoch 043 train loss: 0.1758, val loss: 0.3149 ✓ (new best)
# Epoch 044 train loss: 0.1756, val loss: 0.3112 ✓ (new best)
# Epoch 045 train loss: 0.1746, val loss: 0.3090 ✓ (new best)
# Epoch 046 train loss: 0.1741, val loss: 0.3063 ✓ (new best)
# Epoch 047 train loss: 0.1735, val loss: 0.3032 ✓ (new best)
# Epoch 048 train loss: 0.1733, val loss: 0.2986 ✓ (new best)
# Epoch 049 train loss: 0.1723, val loss: 0.2967 ✓ (new best)
# Epoch 050 train loss: 0.1717, val loss: 0.2945 ✓ (new best)
# Epoch 051 train loss: 0.1716, val loss: 0.2919 ✓ (new best)
# Epoch 052 train loss: 0.1708, val loss: 0.2886 ✓ (new best)
# Epoch 053 train loss: 0.1712, val loss: 0.2870 ✓ (new best)
# Epoch 054 train loss: 0.1702, val loss: 0.2848 ✓ (new best)
# Epoch 055 train loss: 0.1702, val loss: 0.2825 ✓ (new best)
# Epoch 056 train loss: 0.1697, val loss: 0.2808 ✓ (new best)
# Epoch 057 train loss: 0.1693, val loss: 0.2787 ✓ (new best)
# Epoch 058 train loss: 0.1689, val loss: 0.2774 ✓ (new best)
# Epoch 059 train loss: 0.1691, val loss: 0.2755 ✓ (new best)
# Epoch 060 train loss: 0.1688, val loss: 0.2733 ✓ (new best)
# Epoch 061 train loss: 0.1682, val loss: 0.2734 (patience: 1/20)
# Epoch 062 train loss: 0.1679, val loss: 0.2704 ✓ (new best)
# Epoch 063 train loss: 0.1676, val loss: 0.2691 ✓ (new best)
# Epoch 064 train loss: 0.1673, val loss: 0.2675 ✓ (new best)
# Epoch 065 train loss: 0.1673, val loss: 0.2657 ✓ (new best)
# Epoch 066 train loss: 0.1673, val loss: 0.2643 ✓ (new best)
# Epoch 067 train loss: 0.1666, val loss: 0.2627 ✓ (new best)
# Epoch 068 train loss: 0.1665, val loss: 0.2608 ✓ (new best)
# Epoch 069 train loss: 0.1667, val loss: 0.2591 ✓ (new best)
# Epoch 070 train loss: 0.1666, val loss: 0.2576 ✓ (new best)
# Epoch 071 train loss: 0.1667, val loss: 0.2579 (patience: 1/20)
# Epoch 072 train loss: 0.1663, val loss: 0.2546 ✓ (new best)
# Epoch 073 train loss: 0.1662, val loss: 0.2536 ✓ (new best)
# Epoch 074 train loss: 0.1660, val loss: 0.2522 ✓ (new best)
# Epoch 075 train loss: 0.1658, val loss: 0.2519 ✓ (new best)
# Epoch 076 train loss: 0.1651, val loss: 0.2511 ✓ (new best)
# Epoch 077 train loss: 0.1654, val loss: 0.2495 ✓ (new best)
# Epoch 078 train loss: 0.1652, val loss: 0.2497 (patience: 1/20)
# Epoch 079 train loss: 0.1651, val loss: 0.2486 ✓ (new best)
# Epoch 080 train loss: 0.1649, val loss: 0.2477 ✓ (new best)
# Epoch 081 train loss: 0.1647, val loss: 0.2456 ✓ (new best)
# Epoch 082 train loss: 0.1646, val loss: 0.2453 ✓ (new best)
# Epoch 083 train loss: 0.1651, val loss: 0.2447 ✓ (new best)
# Epoch 084 train loss: 0.1644, val loss: 0.2434 ✓ (new best)
# Epoch 085 train loss: 0.1643, val loss: 0.2423 ✓ (new best)
# Epoch 086 train loss: 0.1641, val loss: 0.2411 ✓ (new best)
# Epoch 087 train loss: 0.1643, val loss: 0.2411 (patience: 1/20)
# Epoch 088 train loss: 0.1638, val loss: 0.2407 ✓ (new best)
# Epoch 089 train loss: 0.1636, val loss: 0.2407 (patience: 1/20)
# Epoch 090 train loss: 0.1635, val loss: 0.2390 ✓ (new best)
# Epoch 091 train loss: 0.1633, val loss: 0.2385 ✓ (new best)
# Epoch 092 train loss: 0.1632, val loss: 0.2381 ✓ (new best)
# Epoch 093 train loss: 0.1632, val loss: 0.2366 ✓ (new best)
# Epoch 094 train loss: 0.1631, val loss: 0.2358 ✓ (new best)
# Epoch 095 train loss: 0.1632, val loss: 0.2356 ✓ (new best)
# Epoch 096 train loss: 0.1628, val loss: 0.2346 ✓ (new best)
# Epoch 097 train loss: 0.1630, val loss: 0.2338 ✓ (new best)
# Epoch 098 train loss: 0.1630, val loss: 0.2332 ✓ (new best)
# Epoch 099 train loss: 0.1627, val loss: 0.2329 ✓ (new best)
# Epoch 100 train loss: 0.1628, val loss: 0.2328 ✓ (new best)
# Epoch 101 train loss: 0.1628, val loss: 0.2322 ✓ (new best)
# Epoch 102 train loss: 0.1619, val loss: 0.2321 (patience: 1/20)
# Epoch 103 train loss: 0.1621, val loss: 0.2312 ✓ (new best)
# Epoch 104 train loss: 0.1623, val loss: 0.2310 ✓ (new best)
# Epoch 105 train loss: 0.1624, val loss: 0.2308 ✓ (new best)
# Epoch 106 train loss: 0.1620, val loss: 0.2297 ✓ (new best)
# Epoch 107 train loss: 0.1619, val loss: 0.2291 ✓ (new best)
# Epoch 108 train loss: 0.1618, val loss: 0.2300 (patience: 1/20)
# Epoch 109 train loss: 0.1623, val loss: 0.2286 ✓ (new best)
# Epoch 110 train loss: 0.1618, val loss: 0.2286 (patience: 1/20)
# Epoch 111 train loss: 0.1616, val loss: 0.2275 ✓ (new best)
# Epoch 112 train loss: 0.1616, val loss: 0.2273 ✓ (new best)
# Epoch 113 train loss: 0.1615, val loss: 0.2267 ✓ (new best)
# Epoch 114 train loss: 0.1609, val loss: 0.2270 (patience: 1/20)
# Epoch 115 train loss: 0.1608, val loss: 0.2260 ✓ (new best)
# Epoch 116 train loss: 0.1606, val loss: 0.2254 ✓ (new best)
# Epoch 117 train loss: 0.1610, val loss: 0.2261 (patience: 1/20)
# Epoch 118 train loss: 0.1610, val loss: 0.2255 (patience: 2/20)
# Epoch 119 train loss: 0.1607, val loss: 0.2247 ✓ (new best)
# Epoch 120 train loss: 0.1604, val loss: 0.2236 ✓ (new best)
# Epoch 121 train loss: 0.1608, val loss: 0.2237 (patience: 1/20)
# Epoch 122 train loss: 0.1609, val loss: 0.2236 (patience: 2/20)
# Epoch 123 train loss: 0.1605, val loss: 0.2228 ✓ (new best)
# Epoch 124 train loss: 0.1603, val loss: 0.2228 (patience: 1/20)
# Epoch 125 train loss: 0.1599, val loss: 0.2223 ✓ (new best)
# Epoch 126 train loss: 0.1602, val loss: 0.2220 ✓ (new best)
# Epoch 127 train loss: 0.1597, val loss: 0.2215 ✓ (new best)
# Epoch 128 train loss: 0.1597, val loss: 0.2213 ✓ (new best)
# Epoch 129 train loss: 0.1597, val loss: 0.2217 (patience: 1/20)
# Epoch 130 train loss: 0.1597, val loss: 0.2208 ✓ (new best)
# Epoch 131 train loss: 0.1602, val loss: 0.2211 (patience: 1/20)
# Epoch 132 train loss: 0.1603, val loss: 0.2204 ✓ (new best)
# Epoch 133 train loss: 0.1599, val loss: 0.2195 ✓ (new best)
# Epoch 134 train loss: 0.1597, val loss: 0.2203 (patience: 1/20)
# Epoch 135 train loss: 0.1596, val loss: 0.2194 ✓ (new best)
# Epoch 136 train loss: 0.1596, val loss: 0.2191 ✓ (new best)
# Epoch 137 train loss: 0.1594, val loss: 0.2196 (patience: 1/20)
# Epoch 138 train loss: 0.1596, val loss: 0.2190 (patience: 2/20)
# Epoch 139 train loss: 0.1599, val loss: 0.2182 ✓ (new best)
# Epoch 140 train loss: 0.1594, val loss: 0.2180 ✓ (new best)
# Epoch 141 train loss: 0.1594, val loss: 0.2186 (patience: 1/20)
# Epoch 142 train loss: 0.1593, val loss: 0.2184 (patience: 2/20)
# Epoch 143 train loss: 0.1593, val loss: 0.2170 ✓ (new best)
# Epoch 144 train loss: 0.1594, val loss: 0.2172 (patience: 1/20)
# Epoch 145 train loss: 0.1594, val loss: 0.2160 ✓ (new best)
# Epoch 146 train loss: 0.1591, val loss: 0.2161 (patience: 1/20)
# Epoch 147 train loss: 0.1586, val loss: 0.2169 (patience: 2/20)
# Epoch 148 train loss: 0.1590, val loss: 0.2163 (patience: 3/20)
# Epoch 149 train loss: 0.1584, val loss: 0.2159 ✓ (new best)
# Epoch 150 train loss: 0.1590, val loss: 0.2158 ✓ (new best)
# Epoch 151 train loss: 0.1586, val loss: 0.2155 ✓ (new best)
# Epoch 152 train loss: 0.1585, val loss: 0.2157 (patience: 1/20)
# Epoch 153 train loss: 0.1588, val loss: 0.2147 ✓ (new best)
# Epoch 154 train loss: 0.1586, val loss: 0.2142 ✓ (new best)
# Epoch 155 train loss: 0.1584, val loss: 0.2148 (patience: 1/20)
# Epoch 156 train loss: 0.1586, val loss: 0.2138 ✓ (new best)
# Epoch 157 train loss: 0.1584, val loss: 0.2139 (patience: 1/20)
# Epoch 158 train loss: 0.1584, val loss: 0.2130 ✓ (new best)
# Epoch 159 train loss: 0.1583, val loss: 0.2132 (patience: 1/20)
# Epoch 160 train loss: 0.1585, val loss: 0.2138 (patience: 2/20)
# Epoch 161 train loss: 0.1582, val loss: 0.2131 (patience: 3/20)
# Epoch 162 train loss: 0.1578, val loss: 0.2122 ✓ (new best)
# Epoch 163 train loss: 0.1583, val loss: 0.2127 (patience: 1/20)
# Epoch 164 train loss: 0.1578, val loss: 0.2121 ✓ (new best)
# Epoch 165 train loss: 0.1576, val loss: 0.2128 (patience: 1/20)
# Epoch 166 train loss: 0.1577, val loss: 0.2124 (patience: 2/20)
# Epoch 167 train loss: 0.1579, val loss: 0.2118 ✓ (new best)
# Epoch 168 train loss: 0.1578, val loss: 0.2115 ✓ (new best)
# Epoch 169 train loss: 0.1580, val loss: 0.2129 (patience: 1/20)
# Epoch 170 train loss: 0.1578, val loss: 0.2114 (patience: 2/20)
# Epoch 171 train loss: 0.1575, val loss: 0.2117 (patience: 3/20)
# Epoch 172 train loss: 0.1573, val loss: 0.2115 (patience: 4/20)
# Epoch 173 train loss: 0.1579, val loss: 0.2105 ✓ (new best)
# Epoch 174 train loss: 0.1573, val loss: 0.2108 (patience: 1/20)
# Epoch 175 train loss: 0.1575, val loss: 0.2112 (patience: 2/20)
# Epoch 176 train loss: 0.1577, val loss: 0.2102 ✓ (new best)
# Epoch 177 train loss: 0.1569, val loss: 0.2096 ✓ (new best)
# Epoch 178 train loss: 0.1572, val loss: 0.2100 (patience: 1/20)
# Epoch 179 train loss: 0.1568, val loss: 0.2103 (patience: 2/20)
# Epoch 180 train loss: 0.1568, val loss: 0.2101 (patience: 3/20)
# Epoch 181 train loss: 0.1570, val loss: 0.2100 (patience: 4/20)
# Epoch 182 train loss: 0.1570, val loss: 0.2097 (patience: 5/20)
# Epoch 183 train loss: 0.1570, val loss: 0.2095 ✓ (new best)
# Epoch 184 train loss: 0.1565, val loss: 0.2095 (patience: 1/20)
# Epoch 185 train loss: 0.1572, val loss: 0.2094 (patience: 2/20)
# Epoch 186 train loss: 0.1567, val loss: 0.2090 ✓ (new best)
# Epoch 187 train loss: 0.1569, val loss: 0.2088 ✓ (new best)
# Epoch 188 train loss: 0.1570, val loss: 0.2091 (patience: 1/20)
# Epoch 189 train loss: 0.1567, val loss: 0.2080 ✓ (new best)
# Epoch 190 train loss: 0.1568, val loss: 0.2084 (patience: 1/20)
# Epoch 191 train loss: 0.1568, val loss: 0.2079 (patience: 2/20)
# Epoch 192 train loss: 0.1563, val loss: 0.2082 (patience: 3/20)
# Epoch 193 train loss: 0.1567, val loss: 0.2070 ✓ (new best)
# Epoch 194 train loss: 0.1560, val loss: 0.2080 (patience: 1/20)
# Epoch 195 train loss: 0.1566, val loss: 0.2084 (patience: 2/20)
# Epoch 196 train loss: 0.1557, val loss: 0.2075 (patience: 3/20)
# Epoch 197 train loss: 0.1567, val loss: 0.2075 (patience: 4/20)
# Epoch 198 train loss: 0.1565, val loss: 0.2070 (patience: 5/20)
# Epoch 199 train loss: 0.1563, val loss: 0.2072 (patience: 6/20)
# Epoch 200 train loss: 0.1559, val loss: 0.2067 ✓ (new best)
# Epoch 201 train loss: 0.1561, val loss: 0.2073 (patience: 1/20)
# Epoch 202 train loss: 0.1561, val loss: 0.2070 (patience: 2/20)
# Epoch 203 train loss: 0.1562, val loss: 0.2076 (patience: 3/20)
# Epoch 204 train loss: 0.1564, val loss: 0.2075 (patience: 4/20)
# Epoch 205 train loss: 0.1564, val loss: 0.2063 ✓ (new best)
# Epoch 206 train loss: 0.1562, val loss: 0.2064 (patience: 1/20)
# Epoch 207 train loss: 0.1558, val loss: 0.2060 ✓ (new best)
# Epoch 208 train loss: 0.1551, val loss: 0.2062 (patience: 1/20)
# Epoch 209 train loss: 0.1559, val loss: 0.2071 (patience: 2/20)
# Epoch 210 train loss: 0.1561, val loss: 0.2068 (patience: 3/20)
# Epoch 211 train loss: 0.1561, val loss: 0.2064 (patience: 4/20)
# Epoch 212 train loss: 0.1562, val loss: 0.2067 (patience: 5/20)
# Epoch 213 train loss: 0.1556, val loss: 0.2051 ✓ (new best)
# Epoch 214 train loss: 0.1556, val loss: 0.2061 (patience: 1/20)
# Epoch 215 train loss: 0.1556, val loss: 0.2063 (patience: 2/20)
# Epoch 216 train loss: 0.1558, val loss: 0.2051 (patience: 3/20)
# Epoch 217 train loss: 0.1560, val loss: 0.2050 (patience: 4/20)
# Epoch 218 train loss: 0.1554, val loss: 0.2061 (patience: 5/20)
# Epoch 219 train loss: 0.1554, val loss: 0.2058 (patience: 6/20)
# Epoch 220 train loss: 0.1551, val loss: 0.2049 ✓ (new best)
# Epoch 221 train loss: 0.1552, val loss: 0.2052 (patience: 1/20)
# Epoch 222 train loss: 0.1552, val loss: 0.2062 (patience: 2/20)
# Epoch 223 train loss: 0.1553, val loss: 0.2056 (patience: 3/20)
# Epoch 224 train loss: 0.1549, val loss: 0.2047 ✓ (new best)
# Epoch 225 train loss: 0.1547, val loss: 0.2047 (patience: 1/20)
# Epoch 226 train loss: 0.1548, val loss: 0.2051 (patience: 2/20)
# Epoch 227 train loss: 0.1553, val loss: 0.2047 (patience: 3/20)
# Epoch 228 train loss: 0.1549, val loss: 0.2040 ✓ (new best)
# Epoch 229 train loss: 0.1548, val loss: 0.2044 (patience: 1/20)
# Epoch 230 train loss: 0.1551, val loss: 0.2038 ✓ (new best)
# Epoch 231 train loss: 0.1546, val loss: 0.2036 ✓ (new best)
# Epoch 232 train loss: 0.1551, val loss: 0.2045 (patience: 1/20)
# Epoch 233 train loss: 0.1548, val loss: 0.2036 (patience: 2/20)
# Epoch 234 train loss: 0.1547, val loss: 0.2037 (patience: 3/20)
# Epoch 235 train loss: 0.1548, val loss: 0.2042 (patience: 4/20)
# Epoch 236 train loss: 0.1547, val loss: 0.2037 (patience: 5/20)
# Epoch 237 train loss: 0.1548, val loss: 0.2027 ✓ (new best)
# Epoch 238 train loss: 0.1545, val loss: 0.2037 (patience: 1/20)
# Epoch 239 train loss: 0.1542, val loss: 0.2033 (patience: 2/20)
# Epoch 240 train loss: 0.1543, val loss: 0.2028 (patience: 3/20)
# Epoch 241 train loss: 0.1547, val loss: 0.2033 (patience: 4/20)
# Epoch 242 train loss: 0.1546, val loss: 0.2032 (patience: 5/20)
# Epoch 243 train loss: 0.1541, val loss: 0.2027 (patience: 6/20)
# Epoch 244 train loss: 0.1551, val loss: 0.2026 ✓ (new best)
# Epoch 245 train loss: 0.1543, val loss: 0.2029 (patience: 1/20)
# Epoch 246 train loss: 0.1542, val loss: 0.2023 ✓ (new best)
# Epoch 247 train loss: 0.1548, val loss: 0.2021 ✓ (new best)
# Epoch 248 train loss: 0.1542, val loss: 0.2031 (patience: 1/20)
# Epoch 249 train loss: 0.1545, val loss: 0.2028 (patience: 2/20)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/models/deep/deepmodel.py:254: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Epoch 250 train loss: 0.1544, val loss: 0.2023 (patience: 3/20)
# trained ✓
# Forecasting test: 100%|████████████████████████████████████████████████████████████████████| 102/102 [00:00<00:00, 221.89it/s]
# Test loss: 0.2288
# forecasted ✓
# GATv2LSTMModel(name='gatv2_geographical_neighbors1')

# %%
gatv2_3 = GATv2LSTMModel(gl3, name = 'gatv2_commuer1', verbose = 10)
gatv2_3.set_model_hparams()
gatv2_3.set_global_hparams(**global_hparams)
gatv2_3.train()
gatv2_3.forecast('test')
# Out:
# ==================================================
# ==                gatv2_commuer1                ==
# ==================================================
# model_hparams_set ✓
# global_hparams_set ✓
# Dataloader Snapshot: GraphData(x=(400, 3, 7), y=(400, 1), edge_index=(2, 3905), edge_weight=(3905,))
# Epoch 001 train loss: 0.2833, val loss: 0.5178 ✓ (new best)
# Epoch 002 train loss: 0.2280, val loss: 0.4695 ✓ (new best)
# Epoch 003 train loss: 0.2141, val loss: 0.4480 ✓ (new best)
# Epoch 004 train loss: 0.2040, val loss: 0.4311 ✓ (new best)
# Epoch 005 train loss: 0.1977, val loss: 0.4237 ✓ (new best)
# Epoch 006 train loss: 0.1951, val loss: 0.4164 ✓ (new best)
# Epoch 007 train loss: 0.1939, val loss: 0.4125 ✓ (new best)
# Epoch 008 train loss: 0.1930, val loss: 0.4073 ✓ (new best)
# Epoch 009 train loss: 0.1924, val loss: 0.4059 ✓ (new best)
# Epoch 010 train loss: 0.1921, val loss: 0.4004 ✓ (new best)
# Epoch 011 train loss: 0.1915, val loss: 0.3968 ✓ (new best)
# Epoch 012 train loss: 0.1907, val loss: 0.3924 ✓ (new best)
# Epoch 013 train loss: 0.1900, val loss: 0.3903 ✓ (new best)
# Epoch 014 train loss: 0.1889, val loss: 0.3853 ✓ (new best)
# Epoch 015 train loss: 0.1884, val loss: 0.3826 ✓ (new best)
# Epoch 016 train loss: 0.1871, val loss: 0.3793 ✓ (new best)
# Epoch 017 train loss: 0.1854, val loss: 0.3726 ✓ (new best)
# Epoch 018 train loss: 0.1843, val loss: 0.3699 ✓ (new best)
# Epoch 019 train loss: 0.1831, val loss: 0.3630 ✓ (new best)
# Epoch 020 train loss: 0.1815, val loss: 0.3588 ✓ (new best)
# Epoch 021 train loss: 0.1801, val loss: 0.3549 ✓ (new best)
# Epoch 022 train loss: 0.1787, val loss: 0.3487 ✓ (new best)
# Epoch 023 train loss: 0.1781, val loss: 0.3435 ✓ (new best)
# Epoch 024 train loss: 0.1771, val loss: 0.3387 ✓ (new best)
# Epoch 025 train loss: 0.1764, val loss: 0.3348 ✓ (new best)
# Epoch 026 train loss: 0.1759, val loss: 0.3299 ✓ (new best)
# Epoch 027 train loss: 0.1752, val loss: 0.3266 ✓ (new best)
# Epoch 028 train loss: 0.1742, val loss: 0.3217 ✓ (new best)
# Epoch 029 train loss: 0.1736, val loss: 0.3200 ✓ (new best)
# Epoch 030 train loss: 0.1730, val loss: 0.3144 ✓ (new best)
# Epoch 031 train loss: 0.1727, val loss: 0.3116 ✓ (new best)
# Epoch 032 train loss: 0.1722, val loss: 0.3103 ✓ (new best)
# Epoch 033 train loss: 0.1717, val loss: 0.3063 ✓ (new best)
# Epoch 034 train loss: 0.1713, val loss: 0.3040 ✓ (new best)
# Epoch 035 train loss: 0.1707, val loss: 0.3025 ✓ (new best)
# Epoch 036 train loss: 0.1705, val loss: 0.2981 ✓ (new best)
# Epoch 037 train loss: 0.1704, val loss: 0.2962 ✓ (new best)
# Epoch 038 train loss: 0.1696, val loss: 0.2939 ✓ (new best)
# Epoch 039 train loss: 0.1695, val loss: 0.2915 ✓ (new best)
# Epoch 040 train loss: 0.1694, val loss: 0.2892 ✓ (new best)
# Epoch 041 train loss: 0.1686, val loss: 0.2876 ✓ (new best)
# Epoch 042 train loss: 0.1686, val loss: 0.2841 ✓ (new best)
# Epoch 043 train loss: 0.1685, val loss: 0.2838 ✓ (new best)
# Epoch 044 train loss: 0.1684, val loss: 0.2820 ✓ (new best)
# Epoch 045 train loss: 0.1679, val loss: 0.2803 ✓ (new best)
# Epoch 046 train loss: 0.1679, val loss: 0.2776 ✓ (new best)
# Epoch 047 train loss: 0.1671, val loss: 0.2772 ✓ (new best)
# Epoch 048 train loss: 0.1670, val loss: 0.2749 ✓ (new best)
# Epoch 049 train loss: 0.1671, val loss: 0.2736 ✓ (new best)
# Epoch 050 train loss: 0.1665, val loss: 0.2735 (patience: 1/20)
# Epoch 051 train loss: 0.1665, val loss: 0.2760 (patience: 2/20)
# Epoch 052 train loss: 0.1663, val loss: 0.2691 ✓ (new best)
# Epoch 053 train loss: 0.1660, val loss: 0.2670 ✓ (new best)
# Epoch 054 train loss: 0.1656, val loss: 0.2656 ✓ (new best)
# Epoch 055 train loss: 0.1655, val loss: 0.2642 ✓ (new best)
# Epoch 056 train loss: 0.1651, val loss: 0.2630 ✓ (new best)
# Epoch 057 train loss: 0.1653, val loss: 0.2614 ✓ (new best)
# Epoch 058 train loss: 0.1648, val loss: 0.2613 ✓ (new best)
# Epoch 059 train loss: 0.1647, val loss: 0.2583 ✓ (new best)
# Epoch 060 train loss: 0.1648, val loss: 0.2570 ✓ (new best)
# Epoch 061 train loss: 0.1641, val loss: 0.2556 ✓ (new best)
# Epoch 062 train loss: 0.1639, val loss: 0.2542 ✓ (new best)
# Epoch 063 train loss: 0.1635, val loss: 0.2526 ✓ (new best)
# Epoch 064 train loss: 0.1634, val loss: 0.2529 (patience: 1/20)
# Epoch 065 train loss: 0.1631, val loss: 0.2510 ✓ (new best)
# Epoch 066 train loss: 0.1627, val loss: 0.2496 ✓ (new best)
# Epoch 067 train loss: 0.1627, val loss: 0.2480 ✓ (new best)
# Epoch 068 train loss: 0.1625, val loss: 0.2474 ✓ (new best)
# Epoch 069 train loss: 0.1621, val loss: 0.2452 ✓ (new best)
# Epoch 070 train loss: 0.1619, val loss: 0.2441 ✓ (new best)
# Epoch 071 train loss: 0.1617, val loss: 0.2434 ✓ (new best)
# Epoch 072 train loss: 0.1614, val loss: 0.2428 ✓ (new best)
# Epoch 073 train loss: 0.1609, val loss: 0.2402 ✓ (new best)
# Epoch 074 train loss: 0.1606, val loss: 0.2405 (patience: 1/20)
# Epoch 075 train loss: 0.1600, val loss: 0.2392 ✓ (new best)
# Epoch 076 train loss: 0.1599, val loss: 0.2379 ✓ (new best)
# Epoch 077 train loss: 0.1603, val loss: 0.2368 ✓ (new best)
# Epoch 078 train loss: 0.1597, val loss: 0.2362 ✓ (new best)
# Epoch 079 train loss: 0.1594, val loss: 0.2336 ✓ (new best)
# Epoch 080 train loss: 0.1586, val loss: 0.2322 ✓ (new best)
# Epoch 081 train loss: 0.1587, val loss: 0.2322 (patience: 1/20)
# Epoch 082 train loss: 0.1587, val loss: 0.2323 (patience: 2/20)
# Epoch 083 train loss: 0.1582, val loss: 0.2304 ✓ (new best)
# Epoch 084 train loss: 0.1582, val loss: 0.2293 ✓ (new best)
# Epoch 085 train loss: 0.1577, val loss: 0.2286 ✓ (new best)
# Epoch 086 train loss: 0.1570, val loss: 0.2279 ✓ (new best)
# Epoch 087 train loss: 0.1571, val loss: 0.2273 ✓ (new best)
# Epoch 088 train loss: 0.1567, val loss: 0.2259 ✓ (new best)
# Epoch 089 train loss: 0.1566, val loss: 0.2256 ✓ (new best)
# Epoch 090 train loss: 0.1564, val loss: 0.2252 ✓ (new best)
# Epoch 091 train loss: 0.1560, val loss: 0.2240 ✓ (new best)
# Epoch 092 train loss: 0.1562, val loss: 0.2238 ✓ (new best)
# Epoch 093 train loss: 0.1562, val loss: 0.2230 ✓ (new best)
# Epoch 094 train loss: 0.1556, val loss: 0.2217 ✓ (new best)
# Epoch 095 train loss: 0.1557, val loss: 0.2207 ✓ (new best)
# Epoch 096 train loss: 0.1557, val loss: 0.2207 (patience: 1/20)
# Epoch 097 train loss: 0.1554, val loss: 0.2191 ✓ (new best)
# Epoch 098 train loss: 0.1557, val loss: 0.2201 (patience: 1/20)
# Epoch 099 train loss: 0.1553, val loss: 0.2198 (patience: 2/20)
# Epoch 100 train loss: 0.1550, val loss: 0.2187 ✓ (new best)
# Epoch 101 train loss: 0.1549, val loss: 0.2181 ✓ (new best)
# Epoch 102 train loss: 0.1554, val loss: 0.2184 (patience: 1/20)
# Epoch 103 train loss: 0.1549, val loss: 0.2167 ✓ (new best)
# Epoch 104 train loss: 0.1541, val loss: 0.2159 ✓ (new best)
# Epoch 105 train loss: 0.1547, val loss: 0.2149 ✓ (new best)
# Epoch 106 train loss: 0.1545, val loss: 0.2146 ✓ (new best)
# Epoch 107 train loss: 0.1546, val loss: 0.2151 (patience: 1/20)
# Epoch 108 train loss: 0.1548, val loss: 0.2156 (patience: 2/20)
# Epoch 109 train loss: 0.1545, val loss: 0.2136 ✓ (new best)
# Epoch 110 train loss: 0.1540, val loss: 0.2131 ✓ (new best)
# Epoch 111 train loss: 0.1542, val loss: 0.2123 ✓ (new best)
# Epoch 112 train loss: 0.1544, val loss: 0.2128 (patience: 1/20)
# Epoch 113 train loss: 0.1541, val loss: 0.2127 (patience: 2/20)
# Epoch 114 train loss: 0.1544, val loss: 0.2118 ✓ (new best)
# Epoch 115 train loss: 0.1540, val loss: 0.2112 ✓ (new best)
# Epoch 116 train loss: 0.1537, val loss: 0.2117 (patience: 1/20)
# Epoch 117 train loss: 0.1537, val loss: 0.2116 (patience: 2/20)
# Epoch 118 train loss: 0.1538, val loss: 0.2109 ✓ (new best)
# Epoch 119 train loss: 0.1536, val loss: 0.2100 ✓ (new best)
# Epoch 120 train loss: 0.1533, val loss: 0.2105 (patience: 1/20)
# Epoch 121 train loss: 0.1540, val loss: 0.2094 ✓ (new best)
# Epoch 122 train loss: 0.1536, val loss: 0.2096 (patience: 1/20)
# Epoch 123 train loss: 0.1535, val loss: 0.2101 (patience: 2/20)
# Epoch 124 train loss: 0.1535, val loss: 0.2091 ✓ (new best)
# Epoch 125 train loss: 0.1539, val loss: 0.2094 (patience: 1/20)
# Epoch 126 train loss: 0.1532, val loss: 0.2088 ✓ (new best)
# Epoch 127 train loss: 0.1535, val loss: 0.2084 ✓ (new best)
# Epoch 128 train loss: 0.1532, val loss: 0.2089 (patience: 1/20)
# Epoch 129 train loss: 0.1531, val loss: 0.2064 ✓ (new best)
# Epoch 130 train loss: 0.1535, val loss: 0.2062 ✓ (new best)
# Epoch 131 train loss: 0.1532, val loss: 0.2069 (patience: 1/20)
# Epoch 132 train loss: 0.1530, val loss: 0.2066 (patience: 2/20)
# Epoch 133 train loss: 0.1528, val loss: 0.2056 ✓ (new best)
# Epoch 134 train loss: 0.1532, val loss: 0.2065 (patience: 1/20)
# Epoch 135 train loss: 0.1532, val loss: 0.2063 (patience: 2/20)
# Epoch 136 train loss: 0.1532, val loss: 0.2069 (patience: 3/20)
# Epoch 137 train loss: 0.1528, val loss: 0.2057 (patience: 4/20)
# Epoch 138 train loss: 0.1532, val loss: 0.2059 (patience: 5/20)
# Epoch 139 train loss: 0.1528, val loss: 0.2053 ✓ (new best)
# Epoch 140 train loss: 0.1524, val loss: 0.2041 ✓ (new best)
# Epoch 141 train loss: 0.1522, val loss: 0.2030 ✓ (new best)
# Epoch 142 train loss: 0.1524, val loss: 0.2051 (patience: 1/20)
# Epoch 143 train loss: 0.1524, val loss: 0.2038 (patience: 2/20)
# Epoch 144 train loss: 0.1523, val loss: 0.2027 ✓ (new best)
# Epoch 145 train loss: 0.1523, val loss: 0.2034 (patience: 1/20)
# Epoch 146 train loss: 0.1527, val loss: 0.2049 (patience: 2/20)
# Epoch 147 train loss: 0.1525, val loss: 0.2037 (patience: 3/20)
# Epoch 148 train loss: 0.1526, val loss: 0.2023 ✓ (new best)
# Epoch 149 train loss: 0.1526, val loss: 0.2039 (patience: 1/20)
# Epoch 150 train loss: 0.1518, val loss: 0.2036 (patience: 2/20)
# Epoch 151 train loss: 0.1520, val loss: 0.2011 ✓ (new best)
# Epoch 152 train loss: 0.1526, val loss: 0.2022 (patience: 1/20)
# Epoch 153 train loss: 0.1520, val loss: 0.2020 (patience: 2/20)
# Epoch 154 train loss: 0.1523, val loss: 0.2014 (patience: 3/20)
# Epoch 155 train loss: 0.1522, val loss: 0.2010 ✓ (new best)
# Epoch 156 train loss: 0.1519, val loss: 0.2019 (patience: 1/20)
# Epoch 157 train loss: 0.1522, val loss: 0.2001 ✓ (new best)
# Epoch 158 train loss: 0.1518, val loss: 0.2002 (patience: 1/20)
# Epoch 159 train loss: 0.1518, val loss: 0.2017 (patience: 2/20)
# Epoch 160 train loss: 0.1517, val loss: 0.2011 (patience: 3/20)
# Epoch 161 train loss: 0.1517, val loss: 0.2023 (patience: 4/20)
# Epoch 162 train loss: 0.1517, val loss: 0.2007 (patience: 5/20)
# Epoch 163 train loss: 0.1518, val loss: 0.2013 (patience: 6/20)
# Epoch 164 train loss: 0.1522, val loss: 0.2003 (patience: 7/20)
# lr has been updated from 1.00e-04 to 5.00e-05
# Epoch 165 train loss: 0.1614, val loss: 0.1698 ✓ (new best)
# Epoch 166 train loss: 0.1546, val loss: 0.1661 ✓ (new best)
# Epoch 167 train loss: 0.1522, val loss: 0.1653 ✓ (new best)
# Epoch 168 train loss: 0.1510, val loss: 0.1651 ✓ (new best)
# Epoch 169 train loss: 0.1503, val loss: 0.1654 (patience: 1/20)
# Epoch 170 train loss: 0.1498, val loss: 0.1647 ✓ (new best)
# Epoch 171 train loss: 0.1501, val loss: 0.1651 (patience: 1/20)
# Epoch 172 train loss: 0.1498, val loss: 0.1656 (patience: 2/20)
# Epoch 173 train loss: 0.1493, val loss: 0.1659 (patience: 3/20)
# Epoch 174 train loss: 0.1496, val loss: 0.1656 (patience: 4/20)
# Epoch 175 train loss: 0.1498, val loss: 0.1656 (patience: 5/20)
# Epoch 176 train loss: 0.1493, val loss: 0.1659 (patience: 6/20)
# Epoch 177 train loss: 0.1493, val loss: 0.1652 (patience: 7/20)
# lr has been updated from 5.00e-05 to 2.50e-05
# Epoch 178 train loss: 0.1522, val loss: 0.1581 ✓ (new best)
# Epoch 179 train loss: 0.1495, val loss: 0.1572 ✓ (new best)
# Epoch 180 train loss: 0.1485, val loss: 0.1566 ✓ (new best)
# Epoch 181 train loss: 0.1478, val loss: 0.1563 ✓ (new best)
# Epoch 182 train loss: 0.1475, val loss: 0.1559 ✓ (new best)
# Epoch 183 train loss: 0.1473, val loss: 0.1556 ✓ (new best)
# Epoch 184 train loss: 0.1471, val loss: 0.1555 ✓ (new best)
# Epoch 185 train loss: 0.1474, val loss: 0.1554 (patience: 1/20)
# Epoch 186 train loss: 0.1473, val loss: 0.1554 (patience: 2/20)
# Epoch 187 train loss: 0.1468, val loss: 0.1553 ✓ (new best)
# Epoch 188 train loss: 0.1468, val loss: 0.1552 (patience: 1/20)
# Epoch 189 train loss: 0.1469, val loss: 0.1553 (patience: 2/20)
# Epoch 190 train loss: 0.1470, val loss: 0.1553 (patience: 3/20)
# Epoch 191 train loss: 0.1466, val loss: 0.1554 (patience: 4/20)
# Epoch 192 train loss: 0.1467, val loss: 0.1552 (patience: 5/20)
# Epoch 193 train loss: 0.1465, val loss: 0.1551 ✓ (new best)
# Epoch 194 train loss: 0.1464, val loss: 0.1550 ✓ (new best)
# Epoch 195 train loss: 0.1467, val loss: 0.1550 (patience: 1/20)
# Epoch 196 train loss: 0.1467, val loss: 0.1550 (patience: 2/20)
# Epoch 197 train loss: 0.1467, val loss: 0.1550 (patience: 3/20)
# Epoch 198 train loss: 0.1471, val loss: 0.1550 (patience: 4/20)
# Epoch 199 train loss: 0.1463, val loss: 0.1550 (patience: 5/20)
# Epoch 200 train loss: 0.1463, val loss: 0.1550 (patience: 6/20)
# Epoch 201 train loss: 0.1462, val loss: 0.1552 (patience: 7/20)
# Epoch 202 train loss: 0.1462, val loss: 0.1551 (patience: 8/20)
# Epoch 203 train loss: 0.1463, val loss: 0.1550 (patience: 9/20)
# Epoch 204 train loss: 0.1464, val loss: 0.1549 ✓ (new best)
# Epoch 205 train loss: 0.1467, val loss: 0.1550 (patience: 1/20)
# Epoch 206 train loss: 0.1458, val loss: 0.1548 (patience: 2/20)
# Epoch 207 train loss: 0.1457, val loss: 0.1548 (patience: 3/20)
# Epoch 208 train loss: 0.1464, val loss: 0.1550 (patience: 4/20)
# Epoch 209 train loss: 0.1463, val loss: 0.1549 (patience: 5/20)
# Epoch 210 train loss: 0.1466, val loss: 0.1548 (patience: 6/20)
# Epoch 211 train loss: 0.1460, val loss: 0.1547 ✓ (new best)
# Epoch 212 train loss: 0.1462, val loss: 0.1547 (patience: 1/20)
# Epoch 213 train loss: 0.1459, val loss: 0.1547 (patience: 2/20)
# Epoch 214 train loss: 0.1461, val loss: 0.1547 (patience: 3/20)
# Epoch 215 train loss: 0.1463, val loss: 0.1548 (patience: 4/20)
# Epoch 216 train loss: 0.1462, val loss: 0.1548 (patience: 5/20)
# Epoch 217 train loss: 0.1458, val loss: 0.1548 (patience: 6/20)
# Epoch 218 train loss: 0.1461, val loss: 0.1548 (patience: 7/20)
# Epoch 219 train loss: 0.1459, val loss: 0.1549 (patience: 8/20)
# lr has been updated from 2.50e-05 to 1.25e-05
# Epoch 220 train loss: 0.1464, val loss: 0.1531 ✓ (new best)
# Epoch 221 train loss: 0.1452, val loss: 0.1531 (patience: 1/20)
# Epoch 222 train loss: 0.1452, val loss: 0.1530 ✓ (new best)
# Epoch 223 train loss: 0.1453, val loss: 0.1529 (patience: 1/20)
# Epoch 224 train loss: 0.1448, val loss: 0.1527 ✓ (new best)
# Epoch 225 train loss: 0.1451, val loss: 0.1526 (patience: 1/20)
# Epoch 226 train loss: 0.1450, val loss: 0.1525 ✓ (new best)
# Epoch 227 train loss: 0.1449, val loss: 0.1525 (patience: 1/20)
# Epoch 228 train loss: 0.1451, val loss: 0.1525 (patience: 2/20)
# Epoch 229 train loss: 0.1452, val loss: 0.1524 ✓ (new best)
# Epoch 230 train loss: 0.1449, val loss: 0.1523 (patience: 1/20)
# Epoch 231 train loss: 0.1451, val loss: 0.1523 (patience: 2/20)
# Epoch 232 train loss: 0.1449, val loss: 0.1523 (patience: 3/20)
# Epoch 233 train loss: 0.1453, val loss: 0.1522 ✓ (new best)
# Epoch 234 train loss: 0.1447, val loss: 0.1523 (patience: 1/20)
# Epoch 235 train loss: 0.1452, val loss: 0.1523 (patience: 2/20)
# Epoch 236 train loss: 0.1445, val loss: 0.1523 (patience: 3/20)
# Epoch 237 train loss: 0.1451, val loss: 0.1523 (patience: 4/20)
# Epoch 238 train loss: 0.1446, val loss: 0.1522 (patience: 5/20)
# Epoch 239 train loss: 0.1444, val loss: 0.1522 (patience: 6/20)
# Epoch 240 train loss: 0.1445, val loss: 0.1522 (patience: 7/20)
# Epoch 241 train loss: 0.1449, val loss: 0.1522 (patience: 8/20)
# Epoch 242 train loss: 0.1441, val loss: 0.1521 ✓ (new best)
# Epoch 243 train loss: 0.1442, val loss: 0.1521 (patience: 1/20)
# Epoch 244 train loss: 0.1448, val loss: 0.1521 (patience: 2/20)
# Epoch 245 train loss: 0.1447, val loss: 0.1521 (patience: 3/20)
# Epoch 246 train loss: 0.1447, val loss: 0.1522 (patience: 4/20)
# Epoch 247 train loss: 0.1449, val loss: 0.1522 (patience: 5/20)
# Epoch 248 train loss: 0.1448, val loss: 0.1522 (patience: 6/20)
# Epoch 249 train loss: 0.1446, val loss: 0.1522 (patience: 7/20)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/models/deep/deepmodel.py:254: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Epoch 250 train loss: 0.1442, val loss: 0.1521 (patience: 8/20)
# lr has been updated from 1.25e-05 to 6.25e-06
# trained ✓
# Forecasting test: 100%|████████████████████████████████████████████████████████████████████| 102/102 [00:00<00:00, 219.77it/s]
# Test loss: 0.2285
# forecasted ✓
# GATv2LSTMModel(name='gatv2_commuer1')

# %%
from src.evaluation import Evaluator

evaluation_experiment_gcn   = Evaluator([gatv2_1, gatv2_2, gatv2_3]).add_evaluation()
f_merged_raw_gcn            = evaluation_experiment_gcn.plotter.plot_metric_compilation(subfig_size = (8,4), metrics = ['r2','pearson_corr','node_smape','ccc'], plot_types = ['box','box','box','box']);
# Out:
# computing metrics:   0%|                                                                                | 0/8 [00:00<?, ?it/s]
# computing metrics: 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:08<00:00,  1.01s/it]
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)

# %%
f_merged_raw_gcn.show()

# %%
gatv2_3.show_forecasts(69).show()

# %%
gatv2_2.show_forecasts(26).show()

# %%
gatv2_3.show_forecasts(26).show()

# %%
from src.dataloading import ShallowDataLoaderManager, GraphDataLoaderManager, BaseLineDataLoaderManager
from src.models import PersistenceModel, ClimateologyModel, ClimaScaleModel

sl = BaseLineDataLoaderManager(data_orchestrator)
dl = DeepDataLoaderManager(data_orchestrator).construct_dataloaders()


ps = PersistenceModel(sl)
cm = ClimateologyModel(sl)
cms= ClimaScaleModel(sl)

ps.forecast('test')
raw_f1 = ps.show_forecasts([26], 'test')

cm.forecast('test')
raw_f2 = cm.show_forecasts([26], 'test')

cms.forecast('test')
# Out:
# ClimaScaleModel(name='climascale_model')

# %%
from src.evaluation import Evaluator

evaluation_experiment_gcn   = Evaluator([ps, cm, cms, gatv2_1, gatv2_2, gatv2_3]).add_evaluation()
f_merged_raw_gcn            = evaluation_experiment_gcn.plotter.plot_metric_compilation(subfig_size = (8,4), metrics = ['r2','pearson_corr','node_smape','ccc'], plot_types = ['box','box','box','box']);
# Out:
# computing metrics: 100%|████████████████████████████████████████████████████████████████████████| 8/8 [00:14<00:00,  1.78s/it]
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)
# /scratch/de-schrijvers/projects/infectious_disease_gnn/src/evaluation/evaluationplotter.py:215: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='center', fontsize=8)

# %%
f_merged_raw_gcn.show()

# %%
# Out:
# Moran's I for errors: 0.437
# (Positive = errors clustered, 0 = random, Negative = dispersed)
